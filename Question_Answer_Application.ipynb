# %% [markdown]
# ### Question Answer Application
# The goal of Question Answering is to find the answer to a question given a question and an accompanying context. The predicted answer will be either a span of text from the context or an empty string (indicating the question cannot be answered from the context).

# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simpletransformers
#   Downloading simpletransformers-0.63.11-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (2.27.1)
# Collecting transformers>=4.6.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 59.5 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 26.1 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (2.12.2)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (2022.10.31)
# Collecting tokenizers
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 102.9 MB/s eta 0:00:00
# Collecting streamlit
#   Downloading streamlit-1.21.0-py2.py3-none-any.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 50.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (4.65.0)
# Collecting wandb>=0.10.32
#   Downloading wandb-0.15.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from simpletransformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 23.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.6.0->simpletransformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.6.0->simpletransformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers>=4.6.0->simpletransformers) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (4.5.0)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (3.20.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.21.0-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.5/199.5 kB 23.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (67.7.2)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (5.9.5)
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 20.2 MB/s eta 0:00:00
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.10.32->simpletransformers) (8.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->simpletransformers) (2.0.12)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.6 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 17.7 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets->simpletransformers) (2023.4.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 30.0 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->simpletransformers) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->simpletransformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->simpletransformers) (3.1.0)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (5.3.0)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (13.3.4)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting blinker>=1.0.0
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting watchdog
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 11.6 MB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 81.0 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (8.4.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (6.6.0)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (4.3)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (4.2.2)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.9/dist-packages (from streamlit->simpletransformers) (6.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (2.17.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (3.4.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (2.2.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (1.54.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (0.40.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->simpletransformers) (0.7.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (4.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit->simpletransformers) (3.1.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.10.32->simpletransformers) (1.16.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.4/269.4 kB 29.9 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets->simpletransformers) (23.1.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 15.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=1.4->streamlit->simpletransformers) (3.15.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.2.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal>=1.1->streamlit->simpletransformers) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from validators>=0.2->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit->simpletransformers) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (3.2.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit->simpletransformers) (2023.3)
# Building wheels for collected packages: seqeval, validators, pathtools
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=9962ffce3668a2cf52f70cb5737b96f031dc0dba1694fbab98be2a3771e2080e
#   Stored in directory: /root/.cache/pip/wheels/e2/a5/92/2c80d1928733611c2747a9820e1324a6835524d9411510c142
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=7886b02df8feadda3ad624fd26c83e6cefdc69bed70fae4ac54b90751ace4dd7
#   Stored in directory: /root/.cache/pip/wheels/2d/f0/a8/1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=083a48ef2093815025ce8540662f32eca1a77e0053be1798eaf57fc223c604fd
#   Stored in directory: /root/.cache/pip/wheels/b7/0a/67/ada2a22079218c75a88361c0782855cc72aebc4d18d0289d05
# Successfully built seqeval validators pathtools
# Installing collected packages: tokenizers, sentencepiece, pathtools, xxhash, watchdog, validators, smmap, setproctitle, sentry-sdk, pympler, multidict, frozenlist, docker-pycreds, dill, blinker, async-timeout, yarl, responses, pydeck, multiprocess, huggingface-hub, gitdb, aiosignal, transformers, seqeval, GitPython, aiohttp, wandb, streamlit, datasets, simpletransformers
# Successfully installed GitPython-3.1.31 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 blinker-1.6.2 datasets-2.11.0 dill-0.3.6 docker-pycreds-0.4.0 frozenlist-1.3.3 gitdb-4.0.10 huggingface-hub-0.14.1 multidict-6.0.4 multiprocess-0.70.14 pathtools-0.1.2 pydeck-0.8.1b0 pympler-1.0.1 responses-0.18.0 sentencepiece-0.1.98 sentry-sdk-1.21.0 seqeval-1.2.2 setproctitle-1.3.2 simpletransformers-0.63.11 smmap-5.0.0 streamlit-1.21.0 tokenizers-0.13.3 transformers-4.28.1 validators-0.20.0 wandb-0.15.0 watchdog-3.0.0 xxhash-3.2.0 yarl-1.9.2

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wandb in /usr/local/lib/python3.9/dist-packages (0.15.0)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.9/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (2.27.1)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (1.21.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (8.1.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (3.1.31)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from wandb) (6.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.9/dist-packages (from wandb) (1.3.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)

# %%
import json,ast

# %%
f = open('bert_dataset.txt','r').read()
data = ast.literal_eval(f)

# %%
def modify(con):
  id = con['id']
  imp = con['is_impossible']
  que = con['question']
  qa = con['qas'][0]
  con.pop('qas')
  con.pop('id')
  con.pop('is_impossible')
  con.pop('question')
  con['qas'] = [{'id':id,'answers':[{'answer_start': qa['answer_starts'],'text':qa['text']}],'is_impossible':imp,'question':que}]

# %%
for d in data:
  modify(d)

# %%
import random
import numpy as np
data_np = np.array(data)

# %%
from os import initgroups
indices = np.random.permutation(data_np.shape[0])
train , test = data_np[indices[:620]] , data_np[indices[620:]]

# %%
train , test = train.tolist() , test.tolist()

# %%
import logging

from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# %%
model_type="xlnet"
model_name= "bert-base-cased"
if model_type == "bert":
    model_name = "bert-base-cased"

elif model_type == "roberta":
    model_name = "roberta-base"

elif model_type == "distilbert":
    model_name = "distilbert-base-cased"

elif model_type == "distilroberta":
    model_type = "roberta"
    model_name = "distilroberta-base"

elif model_type == "electra-base":
    model_type = "electra"
    model_name = "google/electra-base-discriminator"

elif model_type == "electra-small":
    model_type = "electra"
    model_name = "google/electra-small-discriminator"

elif model_type == "xlnet":
    model_name = "xlnet-base-cased"

# %%
# Configure the model 
model_args = QuestionAnsweringArgs()
model_args.train_batch_size = 16
model_args.evaluate_during_training = True
model_args.n_best_size=3
model_args.num_train_epochs=5

# %%
### Advanced Methodology
train_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "use_cached_eval_features": True,
    "output_dir": f"outputs/{model_type}",
    "best_model_dir": f"outputs/{model_type}/best_model",
    "evaluate_during_training": True,
    "max_seq_length": 128,
    "num_train_epochs": 5,
    "evaluate_during_training_steps": 1000,
    #"wandb_project": "Question Answer Application",
    #"wandb_kwargs": {"name": model_name},
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "n_best_size":3,
    # "use_early_stopping": True,
    # "early_stopping_metric": "mcc",
    # "n_gpu": 2,
    # "manual_seed": 4,
    # "use_multiprocessing": False,
    "train_batch_size": 128,
    "eval_batch_size": 64,
    # "config": {
    #     "output_hidden_states": True
    # }
}

# %%
train
# Out:
# [{'context': 'end x x Add  to the right side of the deque.. appendleft x x Add  to the left side of the deque.. clear Remove all elements from the deque leaving it ',
#   'qas': [{'id': 145,
#     'answers': [{'answer_start': 73, 'text': 'left'}],
#     'is_impossible': False,
#     'question': 'What does insert i x x insert into the deque at position?'}]},
#  {'context': 'rderedDict dict subclass that remembers the order entries were added. defaultdict dict subclass that calls a factory function to supply missing values',
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 70, 'text': 'defaultdict'}],
#     'is_impossible': False,
#     'question': 'What dict subclass calls a factory function to supply missing values?'}]},
#  {'context': '  and then by the order encountered in the right operand.. . . . . . . elements Return an iterator over elements repeating each as many times as its  ',
#   'qas': [{'id': 141,
#     'answers': [{'answer_start': 73, 'text': 'left'}],
#     'is_impossible': False,
#     'question': 'Elements are returned in the order first encountered?'}]},
#  {'context': 'to remember insertion order.  Math operations  on  objects also preserve order.  Results are ordered  according to when an element is first encountere',
#   'qas': [{'id': 138,
#     'answers': [{'answer_start': 73, 'text': 'order'}],
#     'is_impossible': False,
#     'question': 'Math operations on objects also preserve what?'}]},
#  {'context': 'ize and  position of the underlying data representation.. maxlen If  is not specified or is None, deques may grow to an  arbitrary length.  Otherwise,',
#   'qas': [{'id': 130,
#     'answers': [{'answer_start': 65, 'text': 'If  is not specified'}],
#     'is_impossible': False,
#     'question': 'Is None, deques may grow to an arbitrary length?'}]},
#  {'context': 'Instances of the subclass also have a  helpful docstring (with typename and field_names) and a helpful __repr__()  method which lists the tuple conten',
#   'qas': [{'id': 140,
#     'answers': [{'answer_start': 64, 'text': 'keyword-only arguments'}],
#     'is_impossible': False,
#     'question': 'What did the and parameters become?'}]},
#  {'context': 't(x=33, y=22) \n>>> for partnum, record in inventory.items():\n...  inventory[partnum] = record._replace(price=newprices[partnum], timestamp=time.now())',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 87,
#       'text': 'record._replace(price=newprices[partnum], timestamp=time.now())'}],
#     'is_impossible': False,
#     'question': 'For partnum, record in inventory.items():... inventory[partnum] = what?'}]},
#  {'context': 'ict does not have an efficient equivalent for  OrderedDict’s od.move_to_end(k, last=False) which moves the key  and its associated value to the leftmo',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 61, 'text': 'od.move_to_end(k, last=False)'}],
#     'is_impossible': False,
#     'question': 'What moves the key and its associated value to the leftmost position?'}]},
#  {'context': 't simulates a string object.  The instance’s  content is kept in a regular string object, which is accessible via the  data attribute of UserString in',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 62, 'text': 'in a regular string object'}],
#     'is_impossible': False,
#     'question': "How is the instance's content kept?"}]},
#  {'context': "}, {'lion': 'yellow'})\n>>> d['lion'] = 'orange'  # update an existing key two levels down\n>>> d['snake'] = 'red'  # new keys get added to the topmost ",
#   'qas': [{'id': 129,
#     'answers': [{'answer_start': 74, 'text': 'two'}],
#     'is_impossible': False,
#     'question': 'How many levels down does DeepChainMap display result?'}]},
#  {'context': ' If the insertion would cause a bounded deque to grow beyond ,  an IndexError is raised. New in version 3.5.. pop Remove and return an element from th',
#   'qas': [{'id': 131,
#     'answers': [{'answer_start': 61, 'text': 'grow to an  arbitrary length'}],
#     'is_impossible': False,
#     'question': 'If the deque is not bounded to the specified maximum length, what happens?'}]},
#  {'context': ' self.requests.move_to_end(args)  if len(self.requests) > self.maxrequests:  self.requests.popitem(0)  else:  self.requests.pop(args, None)  self.cache[args] = result',
#   'qas': [{'id': 130,
#     'answers': [{'answer_start': 1,
#       'text': 'self.requests.move_to_end(args)  if len(self.requests) > self.maxrequests:  self.requests.popitem(0)  else:  self.requests.pop(args, None)  self.cache[args] = result'}],
#     'is_impossible': False,
#     'question': 'Self.cache_after: what if len(self.caching) > self.maxsize: self.capacity.popitem(0) return result?'}]},
#  {'context': 'he left side of the deque by appending elements from .  Note, the series of left appends results in reversing the order of  elements in the iterable a',
#   'qas': [{'id': 144,
#     'answers': [{'answer_start': 62, 'text': 'the series of left appends'}],
#     'is_impossible': False,
#     'question': 'What results in reversing the order of elements in the iterable argument?'}]},
#  {'context': 'k”  and is short for “double-ended queue”).  Deques support thread-safe, memory  efficient appends and pops from either side of the deque with approxi',
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 60,
#       'text': 'thread-safe, memory  efficient'}],
#     'is_impossible': False,
#     'question': 'Deques support what kind of appends and pops?'}]},
#  {'context': 'pute the sum of the counts. >>> c = Counter(a=10, b=5, c=0)\n>>> c.total()\n15 New in version 3.10.. fromkeys iterable This class method is not implemen',
#   'qas': [{'id': 140,
#     'answers': [{'answer_start': 71, 'text': 'elements'}],
#     'is_impossible': False,
#     'question': 'what Return an iterator over elements repeating each as many times as its count?'}]},
#  {'context': 'deque is full, when new items are added, a  corresponding number of items are discarded from the opposite end.  Bounded  length deques provide functio',
#   'qas': [{'id': 150,
#     'answers': [{'answer_start': 75, 'text': '.'}],
#     'is_impossible': False,
#     'question': 'Remove the first occurrence of what?'}]},
#  {'context': '. . . . . . elements Return an iterator over elements repeating each as many times as its  count.  Elements are returned in the order first encountere',
#   'qas': [{'id': 154,
#     'answers': [{'answer_start': 74, 'text': 'the'}],
#     'is_impossible': False,
#     'question': 'What is expected to be a sequence of elements?'}]},
#  {'context': 'The same is also true for  update() and subtract() which allow negative and zero values  for both inputs and outputs.. The multiset methods are design',
#   'qas': [{'id': 129,
#     'answers': [{'answer_start': 63, 'text': 'negative and zero values'}],
#     'is_impossible': False,
#     'question': 'Update() and subtract() allow what?'}]},
#  {'context': "te, the iteration order of a ChainMap() is determined by  scanning the mappings last to first:. >>> baseline = {'music': 'bach', 'art': 'rembrandt'}\n>",
#   'qas': [{'id': 130,
#     'answers': [{'answer_start': 71, 'text': 'reference'}],
#     'is_impossible': False,
#     'question': 'A ChainMap incorporates the underlying mappings by what?'}]},
#  {'context': 'eq seq Class that simulates a string object.  The instance’s  content is kept in a regular string object, which is accessible via the  data attribute ',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 46,
#       'text': 'The instance’s  content is kept in a regular string object'}],
#     'is_impossible': False,
#     'question': 'What is accessible via the data attribute of UserString instances?'}]},
#  {'context': 'n  or added-in from another  (or counter).  Like dict.update() but adds counts  instead of replacing them.  Also, the  is expected to be a  sequence o',
#   'qas': [{'id': 148,
#     'answers': [{'answer_start': 72, 'text': 'counts'}],
#     'is_impossible': False,
#     'question': 'What does dict.update() subtract instead of replacing?'}]},
#  {'context': "k', 'l'])\n>>> d.rotate(1)  # right rotation\n>>> d\ndeque(['l', 'g', 'h', 'i', 'j', 'k'])\n>>> d.rotate(-1)  # left rotation\n>>> d\ndeque(['g', 'h', 'i', ",
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 73, 'text': 'G\nH\nI'}],
#     'is_impossible': False,
#     'question': "for elem in d: # iterate over the deque's elements?"}]},
#  {'context': 'titem__(). This means that get() will, like normal  dictionaries, return None as a default rather than using  default_factory.. default_factory This a',
#   'qas': [{'id': 133,
#     'answers': [{'answer_start': 65, 'text': 'propagated unchanged'}],
#     'is_impossible': False,
#     'question': 'What is returned if calling default_factory raises an exception?'}]},
#  {'context': ' "roundrobin(\'ABC\', \'D\', \'EF\') --> A D E B F C"  iterators = deque(map(iter, iterables))  while iterators:  try:  while True:  yield next(iterators[0])  iterators.rotate(-1)  except StopIteration:  # Remove an exhausted iterator',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 1,
#       'text': '"roundrobin(\'ABC\', \'D\', \'EF\') --> A D E B F C"  iterators = deque(map(iter, iterables))  while iterators:  try:  while True:  yield next(iterators[0])  iterators.rotate(-1)  except StopIteration:  # Remove an exhausted iterator'}],
#     'is_impossible': False,
#     'question': 'What does roundrobin(*iterables) --> A D E B F C do?'}]},
#  {'context': 'The regular dict was designed to be very good at mapping  operations.  Tracking insertion order was secondary.',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 49, 'text': 'mapping  operations'}],
#     'is_impossible': False,
#     'question': 'The regular dict was designed to be very good at what?'}]},
#  {'context': 'ge which mappings are searched.  The list should  always contain at least one mapping.. new_child m = None ** kwargs Returns a new ChainMap containing',
#   'qas': [{'id': 138,
#     'answers': [{'answer_start': 74, 'text': 'one'}],
#     'is_impossible': False,
#     'question': 'The list should always contain at least how many mappings?'}]},
#  {'context': 'ed to work with positive integers to represent  running counts; however, care was taken to not unnecessarily preclude use  cases needing other types o',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 73, 'text': 'care'}],
#     'is_impossible': False,
#     'question': 'What was taken to not unnecessarily preclude use cases needing other types or negative values?'}]},
#  {'context': 'inherited from tuples, named tuples support  three additional methods and two attributes.  To prevent conflicts with  field names, the method and attr',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 74, 'text': 'two'}],
#     'is_impossible': False,
#     'question': 'How many attributes do names of methods and attributes have?'}]},
#  {'context': ':. Counter objects have a dictionary interface except that they return a zero  count for missing items instead of raising a KeyError:. Setting a count',
#   'qas': [{'id': 135,
#     'answers': [{'answer_start': 72, 'text': 'zero\n0'}],
#     'is_impossible': False,
#     'question': 'What is the count of a missing element?'}]},
#  {'context': 'rt the following instance variable:. . . __missing__ key key If the default_factory attribute is None, this raises a  KeyError exception with the  as ',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 73, 'text': 'dict'}],
#     'is_impossible': False,
#     'question': 'The remaining functionality is the same as for what class and is not documented?'}]},
#  {'context': 'Unary addition and subtraction are shortcuts for adding an empty counter  or subtracting from an empty counter.',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 49,
#       'text': 'adding an empty counter  or subtracting from an empty counter'}],
#     'is_impossible': False,
#     'question': 'Unary addition and subtraction are shortcuts for what?'}]},
#  {'context': 'a zero  count for missing items instead of raising a KeyError:. Setting a count to zero does not remove an element from a counter.  Use del to remove ',
#   'qas': [{'id': 129,
#     'answers': [{'answer_start': 64, 'text': 'Setting a count to zero'}],
#     'is_impossible': False,
#     'question': 'What does not remove an element from a counter?'}]},
#  {'context': "sts, don't cache\n[0, 1, 4, 9, 16, 25, 36, 49, 64, 81]\n>>> f(4)  # Cache the second request\n16\n>>> f(6)  # Cache the second request\n36\n>>> f(2)  # The ",
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 69, 'text': '[81, 64, 49]'}],
#     'is_impossible': False,
#     'question': 'What are the names of the first and second requests?'}]},
#  {'context': 'of the deque. Remove  old entries with popleft(), add new entries with extend(), and then  reverse the rotation.  With minor variations on that approa',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 71, 'text': 'extend(),'}],
#     'is_impossible': False,
#     'question': 'What does popleft() remove old entries with?'}]},
#  {'context': 'xample of letting user specified command-line arguments take precedence over  environment variables which in turn take precedence over default values:',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 135, 'text': 'default values'}],
#     'is_impossible': False,
#     'question': 'What do environment variables take precedence over?'}]},
#  {'context': 'rporates the underlying mappings by reference.  So, if  one of the underlying mappings gets updated, those changes will be reflected  in ChainMap.. ma',
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 73, 'text': 'a key'}],
#     'is_impossible': False,
#     'question': 'Lookups search the underlying mappings successively until what is found?'}]},
#  {'context': " {'art': 'van gogh', 'opera': 'carmen'}\n>>> list(ChainMap(adjustments, baseline))\n['music', 'art', 'opera']. This gives the same ordering as a series ",
#   'qas': [{'id': 129,
#     'answers': [{'answer_start': 73, 'text': 'first'}],
#     'is_impossible': False,
#     'question': 'Writes, updates, and deletions only operate on which mapping?'}]},
#  {'context': 'Instances of the subclass also have a  helpful docstring (with typename and field_names) and a helpful __repr__()  method which lists the tuple conten',
#   'qas': [{'id': 141,
#     'answers': [{'answer_start': 64, 'text': 'keyword-only arguments'}],
#     'is_impossible': False,
#     'question': 'The and parameters became what?'}]},
#  {'context': 'ar string object, which is accessible via the  data attribute of UserString instances.  The instance’s  contents are initially set to a copy of .  The',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 65, 'text': 'UserString instances'}],
#     'is_impossible': False,
#     'question': 'What is a seq seq Class that simulates a string object?'}]},
#  {'context': ', it is missing from the mapping, so the  default_factory function calls int() to supply a default count of  zero.  The increment operation then build',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 73, 'text': 'int()'}],
#     'is_impossible': False,
#     'question': 'The increment operation builds up the count for each letter for what operation?'}]},
#  {'context': " fieldnames are ['x', 'y', 'z'] and the defaults are  (1, 2), then x will be a required argument, y will default to  1, and z will default to 2.. modu",
#   'qas': [{'id': 145,
#     'answers': [{'answer_start': 81, 'text': 'version 3.7'}],
#     'is_impossible': False,
#     'question': 'When was the parameter and the _source attribute added?'}]},
#  {'context': "s of a deque in reverse\n['i', 'h', 'g']\n>>> 'h' in d  # search the deque\nTrue\n>>> d.extend('jkl')  # add multiple elements at once\n>>> d\ndeque(['g', '",
#   'qas': [{'id': 131,
#     'answers': [{'answer_start': 73, 'text': 'deque'}],
#     'is_impossible': False,
#     'question': 'What is the name of the deque that is searched in reverse?'}]},
#  {'context': "ne, elements() will ignore it. >>> c = Counter(a=4, b=2, c=0, d=-2)\n>>> sorted(c.elements())\n['a', 'a', 'a', 'a', 'b', 'b']. most_common n n n all Ret",
#   'qas': [{'id': 152,
#     'answers': [{'answer_start': 71, 'text': 'iterable'}],
#     'is_impossible': False,
#     'question': 'What class method is not implemented for Counter objects?'}]},
#  {'context': "ault, the  are applied to the rightmost parameters.  For  example, if the fieldnames are ['x', 'y', 'z'] and the defaults are  (1, 2), then x will be ",
#   'qas': [{'id': 135,
#     'answers': [{'answer_start': 61, 'text': 'x will be a required argument'}],
#     'is_impossible': False,
#     'question': "What fieldnames are ['x', 'y', and 'z'], and the defaults are (1, 2)?"}]},
#  {'context': 'ed from an  or from another  (or counter).  Like dict.update() but subtracts counts instead  of replacing them.  Both inputs and outputs may be zero o',
#   'qas': [{'id': 155,
#     'answers': [{'answer_start': 66, 'text': 'raising a KeyError'}],
#     'is_impossible': False,
#     'question': 'What does the count instead of replacing them do?'}]},
#  {'context': 'e  and  parameters became  keyword-only arguments.. module Changed in version 3.6: Added the  parameter.. verbose Changed in version 3.7: Removed the ',
#   'qas': [{'id': 145,
#     'answers': [{'answer_start': 81, 'text': 'version 3.7'}],
#     'is_impossible': False,
#     'question': 'When was the parameter and the _source attribute added?'}]},
#  {'context': ' support was added.. parents Property returning a new ChainMap containing all of the maps in  the current instance except the first one.  This is usef',
#   'qas': [{'id': 146,
#     'answers': [{'answer_start': 74, 'text': 'all'}],
#     'is_impossible': False,
#     'question': 'How many maps are in the current instance except the first?'}]},
#  {'context': '  and then by the order encountered in the right operand.. . . . . . . elements Return an iterator over elements repeating each as many times as its  ',
#   'qas': [{'id': 140,
#     'answers': [{'answer_start': 71, 'text': 'elements'}],
#     'is_impossible': False,
#     'question': 'what Return an iterator over elements repeating each as many times as its count?'}]},
#  {'context': "['elephant']  # remove an existing key one level down\n>>> d  # display result\nDeepChainMap({'zebra': 'black', 'snake': 'red'}, {}, {'lion': 'orange'})",
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 67, 'text': 'self.maps[0][key]'}],
#     'is_impossible': False,
#     'question': 'what is mapping[key] = value return self?'}]},
#  {'context': 'uest has been made more than once.  """  def __init__(self, func, maxsize=128, maxrequests=4096, cache_after=1):  self.requests = OrderedDict()  # { u',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 74, 'text': '128'}],
#     'is_impossible': False,
#     'question': 'What is maxsize?'}]},
#  {'context': '.  If not found, raises a  ValueError.. reverse Reverse the elements of the deque in-place and then return None. New in version 3.2.. rotate n = 1 n n',
#   'qas': [{'id': 152,
#     'answers': [{'answer_start': 46,
#       'text': 'Returns the first match or raises  ValueError if not found'}],
#     'is_impossible': False,
#     'question': 'What does a ValueError do?'}]},
#  {'context': ' Deque objects support the following methods:. Deque objects also provide one read-only attribute:. . . . . . . . . . . . . . . . append x x Add  to t',
#   'qas': [{'id': 136,
#     'answers': [{'answer_start': 74, 'text': 'one'}],
#     'is_impossible': False,
#     'question': 'How many read-only attributes do Deque objects provide?'}]},
#  {'context': 'm an  or added-in from another  (or counter).  Like dict.update() but adds counts  instead of replacing them.  Also, the  is expected to be a  sequenc',
#   'qas': [{'id': 153,
#     'answers': [{'answer_start': 70, 'text': 'adds counts'}],
#     'is_impossible': False,
#     'question': 'What does dict.update() do instead of replacing them?'}]},
#  {'context': "sts the tuple contents in a name=value format.. field_names field_names The  are a sequence of strings such as ['x', 'y'].  Alternatively,  can be a s",
#   'qas': [{'id': 135,
#     'answers': [{'answer_start': 61, 'text': 'x will be a required argument'}],
#     'is_impossible': False,
#     'question': "What fieldnames are ['x', 'y', and 'z'], and the defaults are (1, 2)?"}]},
#  {'context': 'less  important now that the built-in dict class gained the ability  to remember insertion order (this new behavior became guaranteed in  Python 3.7).',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 138, 'text': 'Python 3.7'}],
#     'is_impossible': False,
#     'question': 'In what version of Python was this new behavior guaranteed?'}]},
#  {'context': 'Bag class  in Smalltalk.. Wikipedia entry for Multisets.. C++ multisets  tutorial with examples.. Knuth, Donald. The Art of Computer Programming Volum',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 26, 'text': 'Wikipedia entry for Multisets'}],
#     'is_impossible': False,
#     'question': 'What is a bag class in Smalltalk?'}]},
#  {'context': 'sion 3.7: Removed the  parameter and the _source attribute.. defaults Changed in version 3.7: Added the  parameter and the _field_defaults  attribute.',
#   'qas': [{'id': 145,
#     'answers': [{'answer_start': 81, 'text': 'version 3.7'}],
#     'is_impossible': False,
#     'question': 'When was the parameter and the _source attribute added?'}]},
#  {'context': "entry with a zero count\n>>> del c['sausage']  # del actually removes the entry. New in version 3.1.. Counter Changed in version 3.7: As a dict subclas",
#   'qas': [{'id': 148,
#     'answers': [{'answer_start': 72, 'text': 'counts'}],
#     'is_impossible': False,
#     'question': 'What does dict.update() subtract instead of replacing?'}]},
#  {'context': 'or creating new subcontexts, and a property for  accessing all but the first mapping:. Note, the iteration order of a ChainMap() is determined by  sca',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 53,
#       'text': 'The underlying mappings are stored in a list'}],
#     'is_impossible': False,
#     'question': 'What is public and can be accessed or updated using the attribute?'}]},
#  {'context': 'look-up proceeds normally (returning the list for that key) and the  list.append() operation adds another value to the list. This technique is  simple',
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 69, 'text': 'list.append()'}],
#     'is_impossible': False,
#     'question': 'What operation adds another value to the list?'}]},
#  {'context': 'lf-documenting code.  They can be used wherever regular tuples are used, and  they add the ability to access fields by name instead of position index.',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 135, 'text': 'position index'}],
#     'is_impossible': False,
#     'question': 'Named tamples add the ability to access fields by name instead of what?'}]},
#  {'context': 'Counters support rich comparison operators for equality, subset, and  superset relationships: ==, !=, <, <=, >, >=.  All of those tests treat missing ',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 17, 'text': 'rich comparison operators'}],
#     'is_impossible': False,
#     'question': 'What do Counters support for equality, subset, and superset relationships?'}]},
#  {'context': "w dict which maps field names to their corresponding  values:. >>> p = Point(x=11, y=22)\n>>> p._asdict()\n{'x': 11, 'y': 22}. Changed in version 3.1: R",
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 63, 'text': '>>> p = Point(x=11, y=22)'}],
#     'is_impossible': False,
#     'question': 'Return a new dict which maps field names to their corresponding values?'}]},
#  {'context': "default value must come after any fields without a  default, the  are applied to the rightmost parameters.  For  example, if the fieldnames are ['x', 'y', 'z'] and the defaults are  (1, 2), then x will be a required argument",
#   'qas': [{'id': 130,
#     'answers': [{'answer_start': 67, 'text': 'positional names'}],
#     'is_impossible': False,
#     'question': 'What do invalid fieldnames automatically be replaced with?'}]},
#  {'context': "ogh', 'opera': 'carmen'}\n>>> list(ChainMap(adjustments, baseline))\n['music', 'art', 'opera']. This gives the same ordering as a series of dict.update(",
#   'qas': [{'id': 132,
#     'answers': [{'answer_start': 68, 'text': 'iteration order'}],
#     'is_impossible': False,
#     'question': 'What is determined by scanning a ChainMap()?'}]},
#  {'context': 'ts support the following methods:. Deque objects also provide one read-only attribute:. . . . . . . . . . . . . . . . append x x Add  to the right sid',
#   'qas': [{'id': 134,
#     'answers': [{'answer_start': 68, 'text': 'the tail filter'}],
#     'is_impossible': False,
#     'question': 'Bounded length deques provide functionality similar to what in Unix?'}]},
#  {'context': 'egular tuple\n>>> x, y\n(11, 22)\n>>> p.x + p.y  # fields also accessible by name\n33\n>>> p  # readable __repr__ with a name=value style\nPoint(x=11, y=22)',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 86, 'text': 'p'}],
#     'is_impossible': False,
#     'question': 'What is a readable __repr__ with a name=value style Point(x=11, y=22)?'}]},
#  {'context': 'e = maxsize  # max number of stored return values  self.cache_after = cache_after  def __call__(self, *args):  if args in self.cache:  self.cache.move',
#   'qas': [{'id': 130,
#     'answers': [{'answer_start': 1,
#       'text': 'self.requests.move_to_end(args)  if len(self.requests) > self.maxrequests:  self.requests.popitem(0)  else:  self.requests.pop(args, None)  self.cache[args] = result'}],
#     'is_impossible': False,
#     'question': 'Self.cache_after: what if len(self.caching) > self.maxsize: self.capacity.popitem(0) return result?'}]},
#  {'context': " of contexts\ndel d['x']  # Delete from current context\nlist(d)  # All nested values\nk in d  # Check all nested values\nlen(d)  # Number of nested value",
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 66, 'text': 'All nested values\nk'}],
#     'is_impossible': False,
#     'question': 'How many nested values are in d?'}]},
#  {'context': ' 3.10: In equality tests, missing elements are treated as having zero counts.  Formerly, Counter(a=3) and Counter(a=3, b=0) were considered  distinct.',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 141, 'text': 'distinct'}],
#     'is_impossible': False,
#     'question': 'Counter(a=3) and Counter(b=0) were previously considered what?'}]},
#  {'context': 'ed from an  or from another  (or counter).  Like dict.update() but subtracts counts instead  of replacing them.  Both inputs and outputs may be zero o',
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 60,
#       'text': 'a zero  count for missing items'}],
#     'is_impossible': False,
#     'question': 'What does interface return instead of raising a KeyError?'}]},
#  {'context': 'new_child m = None ** kwargs Returns a new ChainMap containing a new map followed by  all of the maps in the current instance.  If m is specified,  it becomes the new map at the front of the list of mappings; if not  specified, an empty dict is used, so that a call to d.new_child()  is equivalent to: ChainMap',
#   'qas': [{'id': 142,
#     'answers': [{'answer_start': 69, 'text': 'a  attribute'}],
#     'is_impossible': False,
#     'question': 'What method is used for creating subcontexts that can be updated without altering values in any of the parent mappings?'}]},
#  {'context': "w the representation of the deque\ndeque(['f', 'g', 'h', 'i', 'j']) \n>>> d.pop()  # return and remove the rightmost item\n'j'\n>>> d.popleft()  # return ",
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 72, 'text': 'd.pop()'}],
#     'is_impossible': False,
#     'question': 'What is the name of the function that returns and removes the rightmost item?'}]},
#  {'context': '  that matches .. rename Changed in version 3.1: Added support for .. verbose rename Changed in version 3.6: The  and  parameters became  keyword-only',
#   'qas': [{'id': 139,
#     'answers': [{'answer_start': 67, 'text': '.. verbose rename'}],
#     'is_impossible': False,
#     'question': 'What did rename Change in version 3.1: Add support for?'}]},
#  {'context': 'pdate passed map or new empty dict. This method  is used for creating subcontexts that can be updated without altering  values in any of the parent ma',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 53,
#       'text': 'The underlying mappings are stored in a list'}],
#     'is_impossible': False,
#     'question': 'What is public and can be accessed or updated using the attribute?'}]},
#  {'context': 'ot empty, rotating one step to the right is equivalent  to d.appendleft(d.pop()), and rotating one step to the left is  equivalent to d.append(d.pople',
#   'qas': [{'id': 138,
#     'answers': [{'answer_start': 58,
#       'text': 'Add  to the left side of the deque'}],
#     'is_impossible': False,
#     'question': 'What does appendleft do?'}]},
#  {'context': 'y supplanted by the ability to  subclass directly from list; however, this class can be easier  to work with because the underlying list is accessible',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 70, 'text': 'this class'}],
#     'is_impossible': False,
#     'question': 'What can be easier to work with because the underlying list is accessible as an attribute?'}]},
#  {'context': ">>> # Basic example\n>>> Point = namedtuple('Point', ['x', 'y'])\n>>> p = Point(11, y=22)  # instantiate with positional or keyword arguments\n>>> p[0] +",
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 24, 'text': 'Point'}],
#     'is_impossible': False,
#     'question': 'What is the basic example of a namedtuple?'}]},
#  {'context': 'ror.. reverse Reverse the elements of the deque in-place and then return None. New in version 3.2.. rotate n = 1 n n Rotate the deque  steps to the ri',
#   'qas': [{'id': 141,
#     'answers': [{'answer_start': 75, 'text': '.'}],
#     'is_impossible': False,
#     'question': 'What does count x x count the number of deque elements equal to?'}]},
#  {'context': ' Remove the first occurrence of .  If not found, raises a  ValueError.. reverse Reverse the elements of the deque in-place and then return None. New i',
#   'qas': [{'id': 152,
#     'answers': [{'answer_start': 46,
#       'text': 'Returns the first match or raises  ValueError if not found'}],
#     'is_impossible': False,
#     'question': 'What does a ValueError do?'}]},
#  {'context': 'ed without altering  values in any of the parent mappings. Changed in version 3.4: The optional m parameter was added. Changed in version 3.10: Keywor',
#   'qas': [{'id': 144,
#     'answers': [{'answer_start': 70, 'text': 'version 3.4'}],
#     'is_impossible': False,
#     'question': 'When was the optional m parameter added?'}]},
#  {'context': 'ether writes and other mutations apply only to the first mapping or to  any mapping in the chain.. A greatly simplified read-only version of Chainmap.',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 141, 'text': 'Chainmap'}],
#     'is_impossible': False,
#     'question': 'A greatly simplified read-only version of what?'}]},
#  {'context': "e order\ndeque(['l', 'k', 'j', 'i', 'h', 'g'])\n>>> d.clear()  # empty the deque\n>>> d.pop()  # cannot pop from an empty deque\nTraceback (most recent ca",
#   'qas': [{'id': 133,
#     'answers': [{'answer_start': 61,
#       'text': '# empty the deque\n>>> d.pop()'}],
#     'is_impossible': False,
#     'question': 'What does d.clear() do to empty the deque?'}]},
#  {'context': 'in version 3.10: Keyword arguments support was added.. parents Property returning a new ChainMap containing all of the maps in  the current instance e',
#   'qas': [{'id': 147,
#     'answers': [{'answer_start': 55,
#       'text': 'parents Property returning a new ChainMap'}],
#     'is_impossible': False,
#     'question': 'What is useful for skipping the first map in the search?'}]},
#  {'context': 'ed from an  or from another  (or counter).  Like dict.update() but subtracts counts instead  of replacing them.  Both inputs and outputs may be zero o',
#   'qas': [{'id': 153,
#     'answers': [{'answer_start': 70, 'text': 'adds counts'}],
#     'is_impossible': False,
#     'question': 'What does dict.update() do instead of replacing them?'}]},
#  {'context': 'uple is  set to that value.. Named tuple instances do not have per-instance dictionaries, so they are  lightweight and require no more memory than reg',
#   'qas': [{'id': 137,
#     'answers': [{'answer_start': 69, 'text': 'per-instance'}],
#     'is_impossible': False,
#     'question': 'What type of dictionaries do named tuple instances not have?'}]},
#  {'context': 'place and then return None. New in version 3.2.. rotate n = 1 n n Rotate the deque  steps to the right.  If  is negative, rotate  to the left. When th',
#   'qas': [{'id': 142,
#     'answers': [{'answer_start': 68, 'text': 'extend iterable'}],
#     'is_impossible': False,
#     'question': 'What is new in version 3.2?'}]},
#  {'context': ' d[0] to access  the first element.  Indexed access is O(1) at both ends but slows to O(n) in  the middle.  For fast random access, use lists instead.',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 136, 'text': 'lists'}],
#     'is_impossible': False,
#     'question': 'What is a good way to get fast random access?'}]},
#  {'context': 'rder.. New in version 3.1.. . . popitem last = True LIFO FIFO last The popitem() method for ordered dictionaries returns and removes a  (key, value) p',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 71, 'text': 'popitem()'}],
#     'is_impossible': False,
#     'question': 'What method returns and removes a (key, value) pair?'}]},
#  {'context': 'The OrderedDict was designed to be good at reordering operations.  Space efficiency, iteration speed, and the performance of update  operations were s',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 43, 'text': 'reordering operations'}],
#     'is_impossible': False,
#     'question': 'What was the OrderedDict designed to be good at?'}]},
#  {'context': 'namespace based on an  underlying dictionary instead of a tuple.. The dataclasses module provides a decorator and functions for  automatically adding ',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 70, 'text': 'dataclasses'}],
#     'is_impossible': False,
#     'question': 'What module provides a decorator and functions for automatically adding generated special methods to user-defined classes?'}]},
#  {'context': "ounter(['eggs', 'ham'])\n>>> c['bacon']  # count of a missing element is zero\n0. >>> c['sausage'] = 0  # counter entry with a zero count\n>>> del c['sau",
#   'qas': [{'id': 134,
#     'answers': [{'answer_start': 72, 'text': 'zero\n0'}],
#     'is_impossible': False,
#     'question': '# a new counter from an iterable >>> c = Counter(cats=4, dogs=8) What is the count of a missing element?'}]},
#  {'context': 'values())\n[36, 16]\n>>> set(f.requests).isdisjoint(f.cache)\nTrue\n>>> list(map(f, [9, 8, 7]))  # Cache these second requests\n[81, 64, 49]\n>>> list(map(f',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 74, 'text': '16'}],
#     'is_impossible': False,
#     'question': "Cache the second request 36 >>> f(2) # The first request aged out, so don't cache what?"}]},
#  {'context': 'Return a new dictionary-like object.  defaultdict is a subclass of the  built-in dict class.  It overrides one method and adds one writable  instance ',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 38, 'text': 'defaultdict'}],
#     'is_impossible': False,
#     'question': 'What overrides one method and adds one writable instance variable?'}]},
#  {'context': ' __module__ attribute of the named tuple is  set to that value.. Named tuple instances do not have per-instance dictionaries, so they are  lightweight',
#   'qas': [{'id': 133,
#     'answers': [{'answer_start': 67, 'text': 'defaults defaults'}],
#     'is_impossible': False,
#     'question': 'What can be None or an iterable of default values?'}]},
#  {'context': 'deque is full, when new items are added, a  corresponding number of items are discarded from the opposite end.  Bounded  length deques provide functio',
#   'qas': [{'id': 144,
#     'answers': [{'answer_start': 62, 'text': 'the series of left appends'}],
#     'is_impossible': False,
#     'question': 'What results in reversing the order of elements in the iterable argument?'}]},
#  {'context': 'che)\nTrue\n>>> list(map(f, [9, 8, 7]))  # Cache these second requests\n[81, 64, 49]\n>>> list(map(f, [7, 9]))  # Cache hits\n[49, 81]\n>>> list(f.cache.val',
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 69, 'text': '[81, 64, 49]'}],
#     'is_impossible': False,
#     'question': 'What are the names of the first and second requests?'}]},
#  {'context': "t', ['x', 'y'])\n>>> p = Point(11, y=22)  # instantiate with positional or keyword arguments\n>>> p[0] + p[1]  # indexable like the plain tuple (11, 22)",
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 60,
#       'text': 'positional or keyword arguments'}],
#     'is_impossible': False,
#     'question': 'What does p = Point(11, y=22) instantiate with?'}]},
#  {'context': 'current instance except the first one.  This is useful for skipping  the first map in the search.  Use cases are similar to those for the  nonlocal ke',
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 73, 'text': 'a key'}],
#     'is_impossible': False,
#     'question': 'Lookups search the underlying mappings successively until what is found?'}]},
#  {'context': '  set to that value.. Named tuple instances do not have per-instance dictionaries, so they are  lightweight and require no more memory than regular tu',
#   'qas': [{'id': 129,
#     'answers': [{'answer_start': 59,
#       'text': 'letters, digits,  and underscores'}],
#     'is_impossible': False,
#     'question': 'What do valid identifiers consist of?'}]},
#  {'context': ">>> def constant_factory(value):\n...  return lambda: value\n...\n>>> d = defaultdict(constant_factory('<missing>'))\n>>> d.update(name='John', action='ra",
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 67, 'text': 'd'}],
#     'is_impossible': False,
#     'question': 'What does defaultdict do?'}]},
#  {'context': "elem in d:  # iterate over the deque's elements\n...  print(elem.upper())\nG\nH\nI \n>>> d.append('j')  # add a new entry to the right side\n>>> d.appendlef",
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 73, 'text': 'G\nH\nI'}],
#     'is_impossible': False,
#     'question': "for elem in d: # iterate over the deque's elements?"}]},
#  {'context': 'ded deque to grow beyond ,  an IndexError is raised. New in version 3.5.. pop Remove and return an element from the right side of the deque. If no  el',
#   'qas': [{'id': 143,
#     'answers': [{'answer_start': 66, 'text': 'iterable  argument'}],
#     'is_impossible': False,
#     'question': 'Extend the right side of the deque by appending elements from the what?'}]},
#  {'context': 'the first mapping.. A ChainMap incorporates the underlying mappings by reference.  So, if  one of the underlying mappings gets updated, those changes ',
#   'qas': [{'id': 130,
#     'answers': [{'answer_start': 71, 'text': 'reference'}],
#     'is_impossible': False,
#     'question': 'A ChainMap incorporates the underlying mappings by what?'}]},
#  {'context': ' key is encountered for the first time, it is not already in the  mapping; so an entry is automatically created using the default_factory  function which returns an empty list.  The list.append()  operation then attaches the value to the new list',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 1,
#       'text': 'key is encountered for the first time, it is not already in the  mapping; so an entry is automatically created using the default_factory  function which returns an empty list.  The list.append()  operation then attaches the value to the new list'}],
#     'is_impossible': False,
#     'question': 'The list.append() operation attaches the value to which new list?'}]},
#  {'context': 'erations of mappings,  UserDict instances provide the following attribute:. data. A real dictionary used to store the contents of the UserDict  class.',
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 76, 'text': 'data'}],
#     'is_impossible': False,
#     'question': 'What attribute does UserDict provide in addition to supporting methods and operations of mappings?'}]},
#  {'context': 'rely:. Counter objects support additional methods beyond those available for all  dictionaries:. The usual dictionary methods are available for Counte',
#   'qas': [{'id': 130,
#     'answers': [{'answer_start': 57,
#       'text': 'those available for all  dictionaries'}],
#     'is_impossible': False,
#     'question': 'Counter objects support additional methods beyond what?'}]},
#  {'context': 'Error exception with the  as argument. key key If default_factory is not None, it is called without arguments  to provide a default value for the give',
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 44,
#       'text': 'The remaining functionality is the same as for the  dict class'}],
#     'is_impossible': False,
#     'question': 'What is not documented here?'}]},
#  {'context': 'se changes will be reflected  in ChainMap.. maps All of the usual dictionary methods are supported.  In addition, there is a  attribute, a method for ',
#   'qas': [{'id': 151,
#     'answers': [{'answer_start': 67, 'text': 'Keyword arguments'}],
#     'is_impossible': False,
#     'question': 'Added support for what operators?'}]},
#  {'context': 'le  that matches .. rename Changed in version 3.1: Added support for .. verbose rename Changed in version 3.6: The  and  parameters became  keyword-on',
#   'qas': [{'id': 139,
#     'answers': [{'answer_start': 67, 'text': '.. verbose rename'}],
#     'is_impossible': False,
#     'question': 'What did rename Change in version 3.1: Add support for?'}]},
#  {'context': 'er() function.  A reference to d.parents is equivalent to:  ChainMap(*d.maps[1:]).. PEP 584. Changed in version 3.9: Added support for | and |= operat',
#   'qas': [{'id': 149,
#     'answers': [{'answer_start': 60,
#       'text': 'ChainMap(*d.maps[1:]).. PEP 584'}],
#     'is_impossible': False,
#     'question': 'What is equivalent to a reference to d.parents?'}]},
#  {'context': 'ltiple mappings. Counter dict subclass for counting hashable objects. OrderedDict dict subclass that remembers the order entries were added. defaultdi',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 70, 'text': 'OrderedDict'}],
#     'is_impossible': False,
#     'question': 'What subclass remembers the order entries were added?'}]},
#  {'context': "s may be zero or negative. >>> c = Counter(a=4, b=2, c=0, d=-2)\n>>> d = Counter(a=1, b=2, c=3, d=4)\n>>> c.subtract(d)\n>>> c\nCounter({'a': 3, 'b': 0, '",
#   'qas': [{'id': 132,
#     'answers': [{'answer_start': 68, 'text': 'Counter objects'}],
#     'is_impossible': False,
#     'question': 'What are the usual dictionary methods available for?'}]},
#  {'context': ' need for this class has been partially supplanted by the ability to  subclass directly from str; however, this class can be easier  to work with beca',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 54,
#       'text': 'the ability to  subclass directly from str'}],
#     'is_impossible': False,
#     'question': 'What has partially supplanted the need for this class?'}]},
#  {'context': 'oved to the right end if  is true (the default) or to the  beginning if  is false.  Raises KeyError if the  does  not exist: >>> d = OrderedDict.fromk',
#   'qas': [{'id': 131,
#     'answers': [{'answer_start': 69, 'text': 'if  is false'}],
#     'is_impossible': False,
#     'question': 'When is the item moved to the beginning?'}]},
#  {'context': 'ling default_factory raises an exception this exception is  propagated unchanged. This method is called by the __getitem__() method of the  dict class',
#   'qas': [{'id': 133,
#     'answers': [{'answer_start': 65, 'text': 'propagated unchanged'}],
#     'is_impossible': False,
#     'question': 'What is returned if calling default_factory raises an exception?'}]},
#  {'context': ' . . maps A user updateable list of mappings.  The list is ordered from  first-searched to last-searched.  It is the only stored state and can  be mod',
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 64, 'text': 'The underlying mappings'}],
#     'is_impossible': False,
#     'question': 'What is stored in a list?'}]},
#  {'context': "s get added to the topmost dict\n>>> del d['elephant']  # remove an existing key one level down\n>>> d  # display result\nDeepChainMap({'zebra': 'black',",
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 57,
#       'text': 'remove an existing key one level down'}],
#     'is_impossible': False,
#     'question': "if key in mapping: del mapping[key] return raise KeyError(key) >>> d = DeepChainMap('zebra': 'black', 'elephant':'yellow') > > d['lion'] = 'orange' # update an existing key two levels down?"}]},
#  {'context': ' x Add  to the left side of the deque.. clear Remove all elements from the deque leaving it with length 0.. copy Create a shallow copy of the deque. N',
#   'qas': [{'id': 153,
#     'answers': [{'answer_start': 71, 'text': 'reversing'}],
#     'is_impossible': False,
#     'question': 'When the deque is not empty, rotating to the left will do what?'}]},
#  {'context': ' A regular dict can emulate OrderedDict’s od.popitem(last=True)  with d.popitem() which is guaranteed to pop the rightmost (last) item.. A regular dic',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 70, 'text': 'd.popitem()'}],
#     'is_impossible': False,
#     'question': 'What is guaranteed to pop the rightmost item?'}]},
#  {'context': "'], eliminating the keyword  def and the duplicate fieldname abc.. defaults defaults can be None or an iterable of default values.  Since fields with ",
#   'qas': [{'id': 133,
#     'answers': [{'answer_start': 67, 'text': 'defaults defaults'}],
#     'is_impossible': False,
#     'question': 'What can be None or an iterable of default values?'}]},
#  {'context': 'a new tuple subclass named .  The new subclass is used to  create tuple-like objects that have fields accessible by attribute lookup as  well as being',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 66, 'text': 'tuple-like objects'}],
#     'is_impossible': False,
#     'question': 'What is the new subclass used to create?'}]},
#  {'context': ' need for this class has been partially supplanted by the ability to  subclass directly from dict; however, this class can be easier  to work with bec',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 54,
#       'text': 'the ability to  subclass directly from dict'}],
#     'is_impossible': False,
#     'question': 'What has partially supplanted the need for this class?'}]},
#  {'context': " most_common() returns  elements in the counter.  Elements with equal counts are ordered in the order first encountered: >>> Counter('abracadabra').most_common(3)\n[('a', 5), ('b', 2), ('r', 2)]. subtract iterable-or-mapping iterable mapping Elements are subtracted from an  or from another  (or counter).  Like dict.update()",
#   'qas': [{'id': 140,
#     'answers': [{'answer_start': 71, 'text': 'elements'}],
#     'is_impossible': False,
#     'question': 'what Return an iterator over elements repeating each as many times as its count?'}]},
#  {'context': 'A Counter is a dict subclass for counting hashable objects.  It is a collection where elements are stored as dictionary keys  and their counts are sto',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 2, 'text': 'Counter'}],
#     'is_impossible': False,
#     'question': 'What is a dict subclass for counting hashable objects?'}]},
#  {'context': 'A round-robin scheduler can be implemented with  input iterators stored in a deque.  Values are yielded from the active  iterator in position zero.  I',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 0, 'text': 'A round-robin scheduler'}],
#     'is_impossible': False,
#     'question': 'What can be implemented with input iterators stored in a deque?'}]},
#  {'context': "een blue')\n>>> Pixel = namedtuple('Pixel', Point._fields + Color._fields)\n>>> Pixel(11, 22, 128, 255, 0)\nPixel(x=11, y=22, red=128, green=255, blue=0)",
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 84,
#       'text': '11, 22, 128, 255, 0)\nPixel(x=11'}],
#     'is_impossible': False,
# ...
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 112,
#       'text': 'anywhere a regular dictionary is used'}],
#     'is_impossible': False,
#     'question': 'Where can order-insensitive Equality Tests be substituted?'}]},
#  {'context': ' used to  create tuple-like objects that have fields accessible by attribute lookup as  well as being indexable and iterable.  Instances of the subcla',
#   'qas': [{'id': 134,
#     'answers': [{'answer_start': 39,
#       'text': 'fields with a default value must come after any fields without a  default'}],
#     'is_impossible': False,
#     'question': 'Why are fields with a default value applied to the rightmost parameters?'}]},
#  {'context': "Counter(a=1, b=2, c=3, d=4)\n>>> c.subtract(d)\n>>> c\nCounter({'a': 3, 'b': 0, 'c': -3, 'd': -6}) New in version 3.2.. total Compute the sum of the counts. >>> c = Counter(a=10, b=5, c=0)\n>>> c.total()\n15 New in version 3.10.. fromkeys iterable This class method is not implemented for Counter objects.. update iterable-or-mapping iterable mapping iterable Elements are counted from an  or added-in from another  (or counter).  Like dict.update() but adds counts",
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 60,
#       'text': 'a zero  count for missing items'}],
#     'is_impossible': False,
#     'question': 'What does interface return instead of raising a KeyError?'}]},
#  {'context': 'to the deque at position . maxlen If the insertion would cause a bounded deque to grow beyond ,  an IndexError is raised. New in version 3.5.. pop Rem',
#   'qas': [{'id': 129,
#     'answers': [{'answer_start': 58,
#       'text': 'the underlying data representation'}],
#     'is_impossible': False,
#     'question': 'What do pop(0) and insert(0, v) operations change both the size and position of?'}]},
#  {'context': 'ap in the search.  Use cases are similar to those for the  nonlocal keyword used in nested scopes.  The use cases also parallel those for the built-in',
#   'qas': [{'id': 148,
#     'answers': [{'answer_start': 66, 'text': 'dictionary methods'}],
#     'is_impossible': False,
#     'question': 'Use cases are similar to those for what?'}]},
#  {'context': 'e  parameter.. verbose Changed in version 3.7: Removed the  parameter and the _source attribute.. defaults Changed in version 3.7: Added the  paramete',
#   'qas': [{'id': 142,
#     'answers': [{'answer_start': 60,
#       'text': 'the  parameter and the _source'}],
#     'is_impossible': False,
#     'question': 'What was removed in version 3.7?'}]},
#  {'context': "'x y' or 'x, y'.. class for return global pass raise Any valid Python identifier may be used for a fieldname except for names  starting with an underscore",
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 67, 'text': 'defaults defaults'}],
#     'is_impossible': False,
#     'question': 'What can be a single string with each fieldname separated by whitespace and/or commas?'}]},
#  {'context': 'he usual dictionary methods are available for Counter objects  except for two which work differently for counters.. >>> c = Counter()  # a new, empty ',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 39,
#       'text': 'they return a zero  count for missing items instead of raising a KeyError'}],
#     'is_impossible': False,
#     'question': 'Counter objects have a dictionary interface except what?'}]},
#  {'context': 'ing  default_factory.. default_factory This attribute is used by the __missing__() method; it is  initialized from the first argument to the construct',
#   'qas': [{'id': 134,
#     'answers': [{'answer_start': 69, 'text': '__getitem__()'}],
#     'is_impossible': False,
#     'question': 'What method is called when the requested key is not found?'}]},
#  {'context': 'The class, UserDict acts as a wrapper around dictionary objects.  The need for this class has been partially supplanted by the ability to  subclass di',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 11, 'text': 'UserDict'}],
#     'is_impossible': False,
#     'question': 'What class acts as a wrapper around dictionary objects?'}]},
#  {'context': 'arbitrary length.  Otherwise, the deque is bounded to the specified maximum  length.  Once a bounded length deque is full, when new items are added, a',
#   'qas': [{'id': 141,
#     'answers': [{'answer_start': 75, 'text': '.'}],
#     'is_impossible': False,
#     'question': 'What does count x x count the number of deque elements equal to?'}]},
#  {'context': 'llowed to be  any integer value including zero or negative counts.  The Counter  class is similar to bags or multisets in other languages.. iterable m',
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 72, 'text': 'Counter'}],
#     'is_impossible': False,
#     'question': 'What class is similar to bags or multisets in other languages?'}]},
#  {'context': 'deredDict instead of a regular dict.. Changed in version 3.8: Returns a regular dict instead of an OrderedDict.  As of Python 3.7, regular dicts are g',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 72, 'text': 'regular'}],
#     'is_impossible': False,
#     'question': 'What type of dict is used instead of an OrderedDict?'}]},
#  {'context': ' just a special case of  constant functions.  A faster and more flexible way to create constant functions  is to use a lambda function which can suppl',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 46,
#       'text': 'A faster and more flexible way to create constant functions'}],
#     'is_impossible': False,
#     'question': 'How can a lambda function supply any constant value?'}]},
#  {'context': "pleft()  # return and remove the leftmost item\n'f'\n>>> list(d)  # list the contents of the deque\n['g', 'h', 'i']\n>>> d[0]  # peek at leftmost item\n'g'",
#   'qas': [{'id': 129,
#     'answers': [{'answer_start': 72, 'text': 'd\ndeque'}],
#     'is_impossible': False,
#     'question': "What does 'g', 'h', and 'i' do?"}]},
#  {'context': ' always contain at least one mapping.. new_child m = None ** kwargs Returns a new ChainMap containing a new map followed by  all of the maps in the cu',
#   'qas': [{'id': 139,
#     'answers': [{'answer_start': 58,
#       'text': 'a new ChainMap containing a new map'}],
#     'is_impossible': False,
#     'question': 'What follows by all of the maps in the current instance?'}]},
#  {'context': 'ngth.  Once a bounded length deque is full, when new items are added, a  corresponding number of items are discarded from the opposite end.  Bounded  ',
#   'qas': [{'id': 139,
#     'answers': [{'answer_start': 69, 'text': 'all elements'}],
#     'is_impossible': False,
#     'question': 'What does clear remove from the deque leaving it with length 0.'}]},
#  {'context': 'ring operations.  They have become less  important now that the built-in dict class gained the ability  to remember insertion order (this new behavior',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 73, 'text': 'dict'}],
#     'is_impossible': False,
#     'question': 'What class gained the ability to remember insertion order?'}]},
#  {'context': "everse order\ndeque(['l', 'k', 'j', 'i', 'h', 'g'])\n>>> d.clear()  # empty the deque\n>>> d.pop()  # cannot pop from an empty deque\nTraceback (most rece",
#   'qas': [{'id': 133,
#     'answers': [{'answer_start': 61,
#       'text': '# empty the deque\n>>> d.pop()'}],
#     'is_impossible': False,
#     'question': 'What does d.clear() do to empty the deque?'}]},
#  {'context': ">>> # Tally occurrences of words in a list\n>>> cnt = Counter()\n>>> for word in ['red', 'blue', 'red', 'green', 'blue', 'blue']:\n...  cnt[word] += 1\n..",
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 6,
#       'text': 'Tally occurrences of words in a list'}],
#     'is_impossible': False,
#     'question': 'What does cnt = Counter() do?'}]},
#  {'context': 'ts are ordered  according to when an element is first encountered in the left operand  and then by the order encountered in the right operand.. . . . ',
#   'qas': [{'id': 139,
#     'answers': [{'answer_start': 73, 'text': 'left'}],
#     'is_impossible': False,
#     'question': 'Results are ordered according to when an element is first encountered in which operand?'}]},
#  {'context': 'ops on either end. ChainMap dict-like class for creating a single view of multiple mappings. Counter dict subclass for counting hashable objects. Orde',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 59,
#       'text': 'single view of multiple mappings'}],
#     'is_impossible': False,
#     'question': 'ChainMap dict-like class for creating what?'}]},
#  {'context': 'counts from the  most common to the least.  If  is omitted or None,  most_common() returns  elements in the counter.  Elements with equal counts are o',
#   'qas': [{'id': 144,
#     'answers': [{'answer_start': 1,
#       'text': 'most_common n n n all Return a list of the  most common elements and their counts from the  most common to the least.  If  is omitted or None,  most_common()'}],
#     'is_impossible': False,
#     'question': 'What return a list of the most common elements?'}]},
#  {'context': '-or-mapping iterable mapping Elements are subtracted from an  or from another  (or counter).  Like dict.update() but subtracts counts instead  of repl',
#   'qas': [{'id': 147,
#     'answers': [{'answer_start': 58,
#       'text': 'an  or from another  (or counter).'}],
#     'is_impossible': False,
#     'question': 'What are Elements subtracted from?'}]},
#  {'context': "once\n>>> d\ndeque(['g', 'h', 'i', 'j', 'k', 'l'])\n>>> d.rotate(1)  # right rotation\n>>> d\ndeque(['l', 'g', 'h', 'i', 'j', 'k'])\n>>> d.rotate(-1)  # lef",
#   'qas': [{'id': 133,
#     'answers': [{'answer_start': 61,
#       'text': '# empty the deque\n>>> d.pop()'}],
#     'is_impossible': False,
#     'question': 'What does d.clear() do to empty the deque?'}]},
#  {'context': "# peek at leftmost item\n'g'\n>>> d[-1]  # peek at rightmost item\n'i' \n>>> list(reversed(d))  # list the contents of a deque in reverse\n['i', 'h', 'g']\n",
#   'qas': [{'id': 134,
#     'answers': [{'answer_start': 126, 'text': 'd\ndeque'}],
#     'is_impossible': False,
#     'question': 'How does extendleft() reverse the input order?'}]},
#  {'context': "sic', 'art', 'opera']. . . . maps A user updateable list of mappings.  The list is ordered from  first-searched to last-searched.  It is the only stor",
#   'qas': [{'id': 137,
#     'answers': [{'answer_start': 71, 'text': 'The list'}],
#     'is_impossible': False,
#     'question': 'What is the only stored state and can be modified to change which mappings are searched?'}]},
#  {'context': 'To convert a dictionary to a named tuple, use the double-star-operator  (as described in Unpacking Argument Lists):',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 3,
#       'text': 'convert a dictionary to a named tuple'}],
#     'is_impossible': False,
#     'question': 'What does the double-star-operator do?'}]},
#  {'context': ' side of the deque. If no  elements are present, raises an IndexError.. popleft Remove and return an element from the left side of the deque. If no  e',
#   'qas': [{'id': 149,
#     'answers': [{'answer_start': 1,
#       'text': 'pop Remove and return an element from the right side of the deque. If no  elements are present, raises an IndexError.. popleft Remove and return an element from the left side of the deque'}],
#     'is_impossible': False,
#     'question': 'If no elements are present, raises an IndexError.'}]},
#  {'context': 'e is inserted in  the dictionary for the , and returned. If calling default_factory raises an exception this exception is  propagated unchanged. This ',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 38, 'text': 'defaultdict'}],
#     'is_impossible': False,
#     'question': 'What is a subclass of the built-in dict class?'}]},
#  {'context': "class DeepChainMap(ChainMap):  'Variant of ChainMap that allows direct updates to inner scopes'  def __setitem__(self, key, value):  for mapping in se",
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 32, 'text': 'Variant of ChainMap'}],
#     'is_impossible': False,
#     'question': 'What is the class DeepChainMap?'}]},
#  {'context': 'titem__(). This means that get() will, like normal  dictionaries, return None as a default rather than using  default_factory.. default_factory This a',
#   'qas': [{'id': 129,
#     'answers': [{'answer_start': 65, 'text': 'the following method'}],
#     'is_impossible': False,
#     'question': 'What do defaultdict objects support in addition to the standard dict operations?'}]},
#  {'context': "list(ChainMap(adjustments, baseline))\n['music', 'art', 'opera']. This gives the same ordering as a series of dict.update() calls  starting with the last mapping:. >>> combined = baseline.copy()\n>>> combined.update(adjustments)",
#   'qas': [{'id': 150,
#     'answers': [{'answer_start': 98,
#       'text': 'Added support for | and |= operators'}],
#     'is_impossible': False,
#     'question': 'What was changed in version 3.9?'}]},
#  {'context': " names\n('x', 'y') \n>>> Color = namedtuple('Color', 'red green blue')\n>>> Pixel = namedtuple('Pixel', Point._fields + Color._fields)\n>>> Pixel(11, 22, ",
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 73, 'text': 'Pixel'}],
#     'is_impossible': False,
#     'question': "What is namedtuple('Pixel', Point._fields + Color._felds)?"}]},
#  {'context': 'they are  lightweight and require no more memory than regular tuples.. typename To support pickling, the named tuple class should be assigned to a var',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 0, 'text': 'typename'}],
#     'is_impossible': False,
#     'question': 'what Returns a new tuple subclass named?'}]},
#  {'context': 'nd a helpful __repr__()  method which lists the tuple contents in a name=value format.. field_names field_names The  are a sequence of strings such as',
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 66, 'text': 'a name=value format'}],
#     'is_impossible': False,
#     'question': 'What does the __repr__() method list the tuple contents in?'}]},
#  {'context': '__missing__() is  called for any operations besides  __getitem__(). This means that get() will, like normal  dictionaries, return None as a default rather than using  default_factory.. default_factory This attribute is used by the __missing__()',
#   'qas': [{'id': 138,
#     'answers': [{'answer_start': 62, 'text': 'default_factory  attribute'}],
#     'is_impossible': False,
#     'question': 'What is initialized from the first argument to the constructor, if present?'}]},
#  {'context': 'ute, a method for creating new subcontexts, and a property for  accessing all but the first mapping:. Note, the iteration order of a ChainMap() is det',
#   'qas': [{'id': 146,
#     'answers': [{'answer_start': 74, 'text': 'all'}],
#     'is_impossible': False,
#     'question': 'How many maps are in the current instance except the first?'}]},
#  {'context': 'gs)  timestamp, result = self.cache[args]  if time() - timestamp <= self.maxage:  return result  result = self.func(*args)  self.cache[args] = time(),',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 55,
#       'text': 'timestamp <= self.maxage:  return result'}],
#     'is_impossible': False,
#     'question': 'Self.maxsize = maxsize self.maxage = maxage def __call__(self, *args) timestamp, result = self.cache[args] if time() - timetamp = what?'}]},
#  {'context': "c'] is  converted to ['abc', '_1', 'ghi', '_3'], eliminating the keyword  def and the duplicate fieldname abc.. defaults defaults can be None or an it",
#   'qas': [{'id': 132,
#     'answers': [{'answer_start': 74, 'text': 'def'}],
#     'is_impossible': False,
#     'question': 'What keyword does rename If eliminate?'}]},
#  {'context': 'che)\nTrue\n>>> list(map(f, [9, 8, 7]))  # Cache these second requests\n[81, 64, 49]\n>>> list(map(f, [7, 9]))  # Cache hits\n[49, 81]\n>>> list(f.cache.val',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 74, 'text': '16'}],
#     'is_impossible': False,
#     'question': 'What is the name of the second request?'}]}]

# %%
model = QuestionAnsweringModel(
    model_type,model_name, args=train_args
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/467M [00:00<?, ?B/s]
# Some weights of the model checkpoint at xlnet-base-cased were not used when initializing XLNetForQuestionAnswering: ['lm_loss.bias', 'lm_loss.weight']
# - This IS expected if you are initializing XLNetForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLNetForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLNetForQuestionAnswering were not initialized from the model checkpoint at xlnet-base-cased and are newly initialized: ['end_logits.dense_1.weight', 'answer_class.dense_0.weight', 'end_logits.dense_0.bias', 'answer_class.dense_0.bias', 'start_logits.dense.bias', 'end_logits.dense_1.bias', 'end_logits.dense_0.weight', 'start_logits.dense.weight', 'end_logits.LayerNorm.weight', 'answer_class.dense_1.weight', 'end_logits.LayerNorm.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]

# %%
### Remove output folder
# !rm -rf outputs

# %%
# Train the model
model.train_model(train, eval_data=test)
# Out:
# convert squad examples to features:   0%|          | 0/620 [00:00<?, ?it/s]Could not find answer: 'elements' vs. 'left'
# Could not find answer: 'typename and field_names)' vs. 'keyword-only arguments'
# Could not find answer: ', an IndexError is raised.' vs. 'grow to an arbitrary length'
# Could not find answer: 'c.total() 15 New' vs. 'elements'
# Could not find answer: 'are' vs. '.'
# Could not find answer: 'many' vs. 'the'
# Could not find answer: 'mappings' vs. 'reference'
# Could not find answer: ''i', 'j',' vs. 'G H I'
# Could not find answer: 'dictionaries, return None as a default' vs. 'propagated unchanged'
# Could not find answer: 'a zero' vs. 'zero 0'
# Could not find answer: 'default_factory' vs. 'dict'
# Could not find answer: 'Cache the second' vs. '[81, 64, 49]'
# Could not find answer: 'underlying' vs. 'a key'
# Could not find answer: 'baseline))' vs. 'first'
# Could not find answer: 'typename and field_names)' vs. 'keyword-only arguments'
# Could not find answer: 'required argument,' vs. 'version 3.7'
# Could not find answer: 'True' vs. 'deque'
# Could not find answer: '>>> sorted(c.elements())' vs. 'iterable'
# Could not find answer: 'example, if the fieldnames are ['x',' vs. 'x will be a required argument'
# Could not find answer: 'but subtracts counts' vs. 'raising a KeyError'
# Could not find answer: '3.6: Added the' vs. 'version 3.7'
# Could not find answer: 'display result DeepChainMap({'zebra':' vs. 'self.maps[0][key]'
# Could not find answer: 'reverse Reverse the elements of the deque in-place and then return' vs. 'Returns the first match or raises ValueError if not found'
# Could not find answer: 'field_names The are a sequence' vs. 'x will be a required argument'
# Could not find answer: 'the entry.' vs. 'counts'
# Could not find answer: 'accessing all but the first mapping:. Note, the' vs. 'The underlying mappings are stored in a list'
# Could not find answer: 'are applied to the' vs. 'positional names'
# Could not find answer: '['music', 'art',' vs. 'iteration order'
# Could not find answer: 'read-only attribute:.' vs. 'the tail filter'
# Could not find answer: 'e = maxsize # max number of stored return values self.cache_after = cache_after def __call__(self, *args): if args in self.cache: self.cache.move' vs. 'self.requests.move_to_end(args) if len(self.requests) > self.maxrequests: self.requests.popitem(0) else: self.requests.pop(args, None) self.cache[args] = result'
# Could not find answer: 'dict.update() but subtracts counts instead' vs. 'a zero count for missing items'
# Could not find answer: 'map followed' vs. 'a attribute'
# Could not find answer: 'used for creating subcontexts that can be updated' vs. 'The underlying mappings are stored in a list'
# Could not find answer: 'to d.appendleft(d.pop()), and rotating' vs. 'Add to the left side of the deque'
# Could not find answer: 'found, raises a ValueError.. reverse Reverse the elements of' vs. 'Returns the first match or raises ValueError if not found'
# Could not find answer: 'subtracts counts' vs. 'adds counts'
# Could not find answer: 'Rotate the deque' vs. 'extend iterable'
# Could not find answer: 'list(map(f,' vs. '16'
# Could not find answer: 'Named tuple instances' vs. 'defaults defaults'
# Could not find answer: 'number of items are discarded' vs. 'the series of left appends'
# Could not find answer: 'first' vs. 'a key'
# Could not find answer: 'per-instance dictionaries, so they are' vs. 'letters, digits, and underscores'
# Could not find answer: 'version 3.5.. pop Remove' vs. 'iterable argument'
# Could not find answer: 'key If default_factory is not None, it is called without arguments' vs. 'The remaining functionality is the same as for the dict class'
# Could not find answer: 'dictionary methods' vs. 'Keyword arguments'
# Could not find answer: 'd = Counter(a=1,' vs. 'Counter objects'
# Could not find answer: 'ordered from first-searched' vs. 'The underlying mappings'
# Could not find answer: 'the deque' vs. 'reversing'
# Could not find answer: 'counts are' vs. 'elements'
# Could not find answer: 'by scanning the mappings last to first:.' vs. 'list(ChainMap(adjustments, baseline))'
# Could not find answer: 'the series of left appends results' vs. 'thread-safe, memory efficient'
# Could not find answer: 'd['snake']' vs. 'new keys'
# Could not find answer: 'gives the same' vs. 'version 3.4'
# Could not find answer: 'None' vs. 'dict'
# Could not find answer: 'Counter('abracadabra').most_common(3)' vs. 'two'
# Could not find answer: 'returning a new ChainMap containing all' vs. 'list(ChainMap(adjustments, baseline'
# Could not find answer: 'insert(0, v)' vs. 'list objects'
# Could not find answer: 'lements are' vs. 'Counter'
# Could not find answer: 'the tuple' vs. '_source'
# Could not find answer: 'value.. Named tuple instances do' vs. 'Instances of the subclass'
# Could not find answer: 'series of dict.update() calls' vs. 'ChainMap({}, *d.maps).'
# Could not find answer: 'add a new entry to the right side' vs. 'add multiple elements at once'
# Could not find answer: 'keyword def' vs. '_source'
# Could not find answer: 'may grow' vs. 'Deques'
# Could not find answer: 'ValueError.. reverse Reverse' vs. 'all elements'
# Could not find answer: 'result' vs. '1'
# Could not find answer: 'adjustments = {'art': 'van gogh', 'opera':' vs. 'multiple dicts or other mappings'
# Could not find answer: 'Counter('abracadabra').most_common(3)' vs. 'two'
# Could not find answer: 'clear Remove' vs. 'one'
# Could not find answer: 'ChainMap(*d.maps[1:]).. PEP' vs. 'ChainMap({}, *d.maps).'
# Could not find answer: 'reference to d.parents is equivalent to: ChainMap(*d.maps[1:]).. PEP 584. Changed in version 3.9:' vs. 'list(ChainMap(adjustments, baseline)) ['music', 'art', 'opera']. This gives the same ordering'
# Could not find answer: 'match or raises ValueError if not found.' vs. 'the underlying data representation'
# Could not find answer: 'eque (at or after index and before index ). Returns the first match or raises ValueError if not found. New in version 3.5.. insert i x x i Insert' vs. 'pop Remove and return an element from the right side of the deque. If no elements are present, raises an IndexError.. popleft Remove and return an element from the left side of the deque'
# Could not find answer: 'default_factory This attribute' vs. 'defaultdict'
# Could not find answer: 'the named tuple class' vs. 'tuple-like objects'
# Could not find answer: 'an underscore.' vs. 'per-instance'
# Could not find answer: 'specified, an empty dict is used, so' vs. 'scanning the mappings last to first'
# Could not find answer: 'PEP 584. Changed in' vs. 'Keyword arguments'
# Could not find answer: 'when new items are added,' vs. 'a corresponding number'
# Could not find answer: 'elements() will ignore it. >>> c = Counter(a=4, b=2, c=0, d=-2) >>> sorted(c.elements()) ['a', 'a', 'a', 'a', 'b',' vs. 'c Counter({'a': 3, 'b': 0, 'c': -3, 'd': -6}) New in version 3.2.. total Compute the sum of the counts'
# Could not find answer: 'verbose' vs. 'def'
# Could not find answer: 'number of items are discarded' vs. 'an IndexError is raised'
# Could not find answer: 'hit 36 >>>' vs. 'aged out'
# Could not find answer: ''i', 'j', 'k',' vs. 'd.pop()'
# Could not find answer: '>>>' vs. 'ghi'
# Could not find answer: 'updated, those changes will be reflected in' vs. 'Added support for | and |= operators'
# Could not find answer: 'element’s' vs. '>>>'
# Could not find answer: 'Like dict.update() but' vs. 'Setting a count to zero'
# Could not find answer: '15' vs. '>>>'
# Could not find answer: 'deque to grow beyond , an IndexError is raised. New in version 3.5..' vs. 'a corresponding number of items are discarded from the opposite end'
# Could not find answer: 'grow to' vs. 'one'
# Could not find answer: 'regular tuples.. typename To support pickling,' vs. 'letters, digits, and underscores'
# Could not find answer: 'match or raises ValueError' vs. 'an IndexError is raised'
# Could not find answer: 'instance except the first one. This' vs. 'a new ChainMap containing a new map'
# Could not find answer: 'keyword' vs. 'first'
# Could not find answer: ''opera']. This gives the same ordering as a series of' vs. 'if one of the underlying mappings gets updated'
# Could not find answer: 'to d.new_child() is equivalent to: ChainMap({}, *d.maps). If any keyword arguments are specified,' vs. 'list(ChainMap(adjustments, baseline)) ['music', 'art', 'opera']. This gives the same ordering'
# Could not find answer: 'the , and returned.' vs. 'defaultdict'
# Could not find answer: 'index ). Returns the first match or raises ValueError if not found. New' vs. 'a corresponding number of items are discarded from the opposite end'
# Could not find answer: 'first argument to the constructor,' vs. 'The first argument'
# Could not find answer: 'and before' vs. 'left'
# Could not find answer: 'the keyword def and the duplicate fieldname abc.. defaults' vs. 'defaults Changed in version 3.7: Added the parameter'
# Could not find answer: 'ChainMap..' vs. 'in a list'
# Could not find answer: 'support thread-safe, memory efficient appends' vs. 'elements from the iterable argument'
# Could not find answer: 'this raises a KeyError exception' vs. 'default_factory attribute'
# Could not find answer: 'Counter(a=1,' vs. 'left'
# Could not find answer: 'right rotation' vs. 'three'
# Could not find answer: 'extend iterable' vs. 'list objects'
# Could not find answer: 'extend iterable' vs. 'Deques'
# Could not find answer: 'd=-2) >>> d = Counter(a=1, b=2, c=3,' vs. 'an or from another (or counter).'
# Could not find answer: 'O(1)' vs. 'one'
# Could not find answer: 'operations' vs. 'left'
# Could not find answer: 'then x will be a required argument,' vs. 'letters, digits, and underscores'
# Could not find answer: 'than one,' vs. 'zero 0'
# Could not find answer: 'specified, an empty dict is used,' vs. 'a single empty dictionary'
# Could not find answer: ''i'] >>> d[0] # peek at leftmost item' vs. 'make a new deque in reverse order'
# Could not find answer: '__missing__ key key If' vs. 'default_factory'
# Could not find answer: 'left-to-right (using append())' vs. 'extend iterable'
# Could not find answer: 'Like dict.update() but' vs. 'Setting a count to zero'
# Could not find answer: 'ValueError' vs. 'IndexError'
# Could not find answer: 'the usual dictionary methods are' vs. 'ChainMap(*d.maps[1:]).. PEP 584'
# Could not find answer: 'the first one.' vs. 'first mapping'
# Could not find answer: 'maxlen' vs. 'Deques'
# Could not find answer: 'left-to-right (using append())' vs. 'extend iterable'
# Could not find answer: 'indexable and iterable.' vs. 'defaults defaults'
# Could not find answer: 'the counts. >>>' vs. 'insertion order'
# Could not find answer: 'extend iterable' vs. 'Deque'
# Could not find answer: 'the current instance' vs. 'iteration order'
# Could not find answer: ''opera']. This gives the same ordering' vs. 'Keyword arguments support'
# Could not find answer: '# Cache the second' vs. 'move to front 16'
# Could not find answer: '['music', 'art', 'opera']. This gives the same' vs. 'scanning the mappings last to first'
# Could not find answer: '>>> list(ChainMap(adjustments, baseline))' vs. 'parents Property returning a new ChainMap'
# Could not find answer: 'requests, don't cache [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]' vs. '81, 64, 49] >>> list(map(f, [7, 9])) # Cache hits [49, 81]'
# Could not find answer: 'then return None. New in version' vs. 'the series of left appends'
# Could not find answer: 'key key' vs. 'first'
# Could not find answer: '15 New in' vs. 'Counter'
# Could not find answer: 'Named tuple' vs. 'invalid'
# Could not find answer: 'besides __getitem__(). This' vs. 'the following method'
# Could not find answer: 'dictionary' vs. 'order'
# Could not find answer: 'Property returning a new ChainMap containing all of the' vs. 'if one of the underlying mappings gets updated'
# Could not find answer: 'function_result } self.func = func self.maxrequests = maxrequests # max number of uncached requests self.max' vs. 'self.cache[args] = result if len(self.cache) > self.maxsize: self.cache.popitem(0) return result'
# Could not find answer: 'bounded to the specified' vs. 'an IndexError is raised'
# Could not find answer: 'the is expected to' vs. 'any integer value'
# Could not find answer: 'd.extendleft('abc') # extendleft()' vs. 'add multiple elements at once'
# Could not find answer: 'is not specified or is' vs. 'If is not specified'
# Could not find answer: 'Like dict.update()' vs. 'Counter objects'
# Could not find answer: 'but adds counts instead' vs. 'raising a KeyError'
# Could not find answer: 'than one,' vs. 'zero 0'
# Could not find answer: 'differently' vs. 'iterable'
# Could not find answer: 'besides __getitem__().' vs. 'defaultdict'
# Could not find answer: 'invalid fieldnames' vs. '.. verbose rename'
# Could not find answer: 'dict.update()' vs. 'Counter'
# Could not find answer: 'maps in the current' vs. 'reference'
# Could not find answer: 'first mapping:.' vs. 'The list'
# Could not find answer: 'specified, the new deque is empty..' vs. 'grow to an arbitrary length'
# Could not find answer: 'values. Counts are allowed' vs. 'insertion order'
# Could not find answer: 'propagated unchanged.' vs. 'the same'
# Could not find answer: 'that __missing__()' vs. 'default_factory'
# Could not find answer: 'defined, the __module__ attribute of the named tuple is' vs. 'defaults Changed in version 3.7: Added the parameter'
# Could not find answer: 'None)' vs. '1'
# Could not find answer: 'length.' vs. 'maxlen'
# Could not find answer: 'gives' vs. 'one'
# Could not find answer: 'If is omitted or None, most_common() returns' vs. 'If an element’s count is less than one'
# Could not find answer: 'example 'x y' or 'x, y'..' vs. 'named tuple class'
# Could not find answer: 'a name=value' vs. 'that value..'
# Could not find answer: 'per-instance dictionaries, so' vs. 'a name=value format'
# Could not find answer: '3.5.. pop' vs. 'count'
# Could not find answer: 'e = maxsize # max number of stored return values self.cache_after = cache_after def __call__(self, *args): if args in self.cache: self.cache.move' vs. 'self.requests.move_to_end(args) if len(self.requests) > self.maxrequests: self.requests.popitem(0) else: self.requests.pop(args, None) self.cache[args] = result'
# Could not find answer: 'from another (or counter). Like dict.update() but subtracts counts instead' vs. 'they return a zero count for missing items instead of raising a KeyError'
# Could not find answer: 'it with length 0.. copy' vs. 'a corresponding number'
# Could not find answer: '['x', 'y',' vs. 'invalid'
# Could not find answer: 'match or raises ValueError' vs. 'an IndexError is raised'
# Could not find answer: 'usual dictionary methods are' vs. 'a single empty dictionary'
# Could not find answer: 'first one.' vs. 'The list'
# Could not find answer: 'return and remove the leftmost item' vs. 'add a new entry to the left side'
# Could not find answer: 'd.append(d.popleft()).. maxlen' vs. 'If is not specified'
# Could not find answer: 'equivalent to: ChainMap({}, *d.maps).' vs. 'ChainMap(*d.maps[1:]).. PEP 584'
# Could not find answer: 'raising a KeyError:.' vs. 'adds counts'
# Could not find answer: 'abc.. defaults defaults' vs. 'a name=value format'
# Could not find answer: 'a new' vs. 'deque'
# Could not find answer: 'the new deque' vs. 'IndexError'
# Could not find answer: 'raises' vs. '.'
# Could not find answer: 'eliminating the keyword def and the' vs. 'the parameter and the _source'
# Could not find answer: 'results in reversing the order' vs. 'O(n) memory movement costs'
# Could not find answer: 'right rotation' vs. 'd.popleft()'
# Could not find answer: 'may be' vs. 'Counter'
# Could not find answer: 'max number' vs. '128'
# Could not find answer: 'deque(['l', 'k', 'j',' vs. 'd.popleft()'
# Could not find answer: 'rotating one' vs. 'reversing'
# convert squad examples to features:   0%|          | 1/620 [00:01<11:17,  1.09s/it]Could not find answer: 'result DeepChainMap({'zebra':' vs. 'self.maps'
# Could not find answer: 'many times' vs. 'order'
# Could not find answer: 'mapping.. A ChainMap incorporates' vs. 'dictionary methods'
# Could not find answer: 'Bounded length' vs. 'Deques'
# Could not find answer: 'the left' vs. 'Remove'
# Could not find answer: 'second request 36 >>> f(2)' vs. 'f(6) # Cache hit 36'
# Could not find answer: 'fieldnames' vs. 'def'
# Could not find answer: 'placing them.' vs. 'Counter'
# Could not find answer: 'deque(['l', 'g', 'h', 'i', 'j', 'k']) >>>' vs. 'add a new entry to the left side'
# Could not find answer: 'deque in' vs. 'd deque'
# Could not find answer: 'deque with' vs. 'Traceback'
# Could not find answer: 'is less than one,' vs. 'any integer value'
# Could not find answer: 'dictionary methods' vs. 'an empty dict'
# Could not find answer: 'available for' vs. 'two'
# Could not find answer: 'all Return a list of the' vs. 'elements in the counter'
# Could not find answer: 'queue”). Deques support' vs. 'iterable argument'
# Could not find answer: 'available for all dictionaries:. The usual' vs. 'an or from another (or counter).'
# Could not find answer: 'contrast, writes, updates, and deletions only' vs. 'parents Property returning a new ChainMap'
# Could not find answer: 'the rightmost parameters.' vs. 'keyword-only arguments'
# Could not find answer: 'are counted' vs. 'Counter'
# Could not find answer: 'counter). Like dict.update() but subtracts' vs. 'those available for all dictionaries'
# Could not find answer: ''van gogh', 'opera': 'carmen'} >>>' vs. 'multiple dicts or other mappings'
# Could not find answer: 'the named' vs. 'typename'
# Could not find answer: 'gives the' vs. 'in a list'
# Could not find answer: 'fieldnames are ['x', 'y', 'z'] and the' vs. 'letters, digits, and underscores'
# Could not find answer: 'the deque by appending elements from' vs. 'Add to the left side of the deque'
# Could not find answer: ''_1', 'ghi', '_3'], eliminating' vs. 'Instances of the subclass'
# Could not find answer: 'Rotate the deque' vs. 'extend iterable'
# Could not find answer: 'allowed to be any' vs. 'zero or negative'
# Could not find answer: 'equivalent to: ChainMap({}, *d.maps). If any' vs. 'list(ChainMap(adjustments, baseline))'
# Could not find answer: ''k']) >>> d.rotate(-1)' vs. 'd deque'
# Could not find answer: 'deque(reversed(d))' vs. 'three'
# Could not find answer: 'them. Also, the is expected to be a sequence' vs. 'If an element’s count is less than one'
# Could not find answer: 'that have fields accessible by attribute lookup as well as being indexable' vs. 'fields with a default value must come after any fields without a default'
# Could not find answer: 'Counter({'a': 3, 'b': 0, 'c': -3, 'd':' vs. 'a zero count for missing items'
# Could not find answer: 'cause a bounded deque to grow beyond' vs. 'the underlying data representation'
# Could not find answer: 'nonlocal keyword used in' vs. 'dictionary methods'
# Could not find answer: 'parameter and the _source attribute..' vs. 'the parameter and the _source'
# Could not find answer: 'Python identifier may' vs. 'defaults defaults'
# Could not find answer: 'available for Counter objects except for two which work differently for counters..' vs. 'they return a zero count for missing items instead of raising a KeyError'
# Could not find answer: '__missing__()' vs. '__getitem__()'
# Could not find answer: 'maximum' vs. '.'
# Could not find answer: 'the contents' vs. 'd deque'
# Could not find answer: '** kwargs Returns a new ChainMap containing' vs. 'a new ChainMap containing a new map'
# Could not find answer: 'added, a corresponding' vs. 'all elements'
# Could not find answer: 'counts from the most common to the least. If is omitted or None, most_common() returns elements in the counter. Elements with equal counts are o' vs. 'most_common n n n all Return a list of the most common elements and their counts from the most common to the least. If is omitted or None, most_common()'
# Could not find answer: 'd.rotate(1) # right rotation >>> d deque(['l',' vs. '# empty the deque >>> d.pop()'
# Could not find answer: 'reverse' vs. 'd deque'
# Could not find answer: 'side of the deque. If no elements are present, raises an IndexError.. popleft Remove and return an element from the left side of the deque. If no e' vs. 'pop Remove and return an element from the right side of the deque. If no elements are present, raises an IndexError.. popleft Remove and return an element from the left side of the deque'
# Could not find answer: 'the , and returned.' vs. 'defaultdict'
# Could not find answer: 'dictionaries, return None as a default' vs. 'the following method'
# Could not find answer: 'a series of dict.update() calls starting' vs. 'Added support for | and |= operators'
# Could not find answer: 'they are' vs. 'typename'
# Could not find answer: '__getitem__(). This means that get()' vs. 'default_factory attribute'
# Could not find answer: '64,' vs. '16'
# convert squad examples to features: 100%|██████████| 620/620 [00:01<00:00, 455.61it/s]
# add example index and unique id: 100%|██████████| 620/620 [00:00<00:00, 722753.89it/s]
# Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Running Epoch 0 of 5:   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.9/dist-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
#
# convert squad examples to features:   0%|          | 0/69 [00:00<?, ?it/s]
# convert squad examples to features: 100%|██████████| 69/69 [00:00<00:00, 496.11it/s]
#
# add example index and unique id: 100%|██████████| 69/69 [00:00<00:00, 271488.72it/s]
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]
# Running Epoch 1 of 5:   0%|          | 0/3 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]
# Running Epoch 2 of 5:   0%|          | 0/3 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]
# Running Epoch 3 of 5:   0%|          | 0/3 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]
# Running Epoch 4 of 5:   0%|          | 0/3 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]
# (15,
#  {'global_step': [3, 6, 9, 12, 15],
#   'correct': [0, 0, 0, 0, 0],
#   'similar': [21, 21, 21, 21, 21],
#   'incorrect': [4, 4, 4, 4, 4],
#   'train_loss': [9.041668030536126e+29,
#    8.958335262632815e+29,
#    8.958336018211452e+29,
#    8.791668971247556e+29,
#    8.791669726826193e+29],
#   'eval_loss': [0.05257009156048298,
#    0.05257009156048298,
#    0.07513132691383362,
#    0.03290613926947117,
#    0.031262872740626335]})

# %%
test
# Out:
# [{'context': ' If the insertion would cause a bounded deque to grow beyond ,  an IndexError is raised. New in version 3.5.. pop Remove and return an element from th',
#   'qas': [{'id': 146,
#     'answers': [{'answer_start': 64, 'text': 'an IndexError is raised'}],
#     'is_impossible': False,
#     'question': 'What happens if the insertion causes a bounded deque to be inserted?'}]},
#  {'context': 'n to supporting the methods and operations of mutable sequences,  UserList instances provide the following attribute:. data. A real list object used t',
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 66, 'text': 'UserList instances'}],
#     'is_impossible': False,
#     'question': 'What provides the following attribute?'}]},
#  {'context': "\n>>> list(combined)\n['music', 'art', 'opera']. . . . maps A user updateable list of mappings.  The list is ordered from  first-searched to last-search",
#   'qas': [{'id': 136,
#     'answers': [{'answer_start': 69, 'text': 'first mapping'}],
#     'is_impossible': False,
#     'question': 'What is the only stored state?'}]},
#  {'context': '6: The  and  parameters became  keyword-only arguments.. module Changed in version 3.6: Added the  parameter.. verbose Changed in version 3.7: Removed',
#   'qas': [{'id': 136,
#     'answers': [{'answer_start': 69, 'text': 'that value..'}],
#     'is_impossible': False,
#     'question': 'If module is defined, the __module__ attribute of the named tuple is set to what value?'}]},
#  {'context': 'the name is pronounced “deck”  and is short for “double-ended queue”).  Deques support thread-safe, memory  efficient appends and pops from either sid',
#   'qas': [{'id': 151,
#     'answers': [{'answer_start': 72, 'text': 'Remove'}],
#     'is_impossible': False,
#     'question': 'Return an element from the left side of the deque.'}]},
#  {'context': ' Count the number of deque elements equal to . New in version 3.2.. extend iterable Extend the right side of the deque by appending elements from the ',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 72, 'text': 'Deques'}],
#     'is_impossible': False,
#     'question': 'What is a generalization of stacks and queues?'}]},
#  {'context': 'e = maxsize  # max number of stored return values  self.cache_after = cache_after  def __call__(self, *args):  if args in self.cache:  self.cache.move',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 6,
#       'text': 'MultiHitLRUCache:  """ LRU cache'}],
#     'is_impossible': False,
#     'question': 'What class defers caching a result until it has been requested multiple times?'}]},
#  {'context': " # left rotation\n>>> d\ndeque(['g', 'h', 'i', 'j', 'k', 'l']) \n>>> deque(reversed(d))  # make a new deque in reverse order\ndeque(['l', 'k', 'j', 'i', '",
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 72, 'text': 'd.pop()'}],
#     'is_impossible': False,
#     'question': 'What is the name of the function that returns and removes the rightmost item?'}]},
#  {'context': 'ave a dictionary interface except that they return a zero  count for missing items instead of raising a KeyError:. Setting a count to zero does not re',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 39,
#       'text': 'they return a zero  count for missing items instead of raising a KeyError'}],
#     'is_impossible': False,
#     'question': 'Counter objects have a dictionary interface except what?'}]},
#  {'context': "d', 1), ('blue', 2), ('red', 3), ('blue', 4), ('red', 1), ('blue', 4)]\n>>> d = defaultdict(set)\n>>> for k, v in s:\n...  d[k].add(v)\n...\n>>> sorted(d.i",
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 75, 'text': 'd'}],
#     'is_impossible': False,
#     'question': 'What is the defaultdict(set) for k, v in s?'}]},
#  {'context': ' deque slicing and  deletion.  For example, a pure Python implementation of del d[n] relies on  the rotate() method to position elements to be popped:',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 96, 'text': 'the rotate() method'}],
#     'is_impossible': False,
#     'question': 'What does a pure Python implementation of del d[n] depend on?'}]},
#  {'context': 'ose rename Changed in version 3.6: The  and  parameters became  keyword-only arguments.. module Changed in version 3.6: Added the  parameter.. verbose',
#   'qas': [{'id': 141,
#     'answers': [{'answer_start': 64, 'text': 'keyword-only arguments'}],
#     'is_impossible': False,
#     'question': 'The and parameters became what?'}]},
#  {'context': 'rited the capability to remember insertion order.  Math operations  on  objects also preserve order.  Results are ordered  according to when an elemen',
#   'qas': [{'id': 130,
#     'answers': [{'answer_start': 57,
#       'text': 'those available for all  dictionaries'}],
#     'is_impossible': False,
#     'question': 'Counter objects support additional methods beyond what?'}]},
#  {'context': 'titem__(). This means that get() will, like normal  dictionaries, return None as a default rather than using  default_factory.. default_factory This a',
#   'qas': [{'id': 136,
#     'answers': [{'answer_start': 73, 'text': 'None'}],
#     'is_impossible': False,
#     'question': 'What will get(), like normal dictionaries, return instead of using default_factory?'}]},
#  {'context': "'], eliminating the keyword  def and the duplicate fieldname abc.. defaults defaults can be None or an iterable of default values.  Since fields with ",
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 67, 'text': 'defaults defaults'}],
#     'is_impossible': False,
#     'question': 'What can be a single string with each fieldname separated by whitespace and/or commas?'}]},
#  {'context': '= None ** kwargs Returns a new ChainMap containing a new map followed by  all of the maps in the current instance.  If m is specified,  it becomes the',
#   'qas': [{'id': 146,
#     'answers': [{'answer_start': 74, 'text': 'all'}],
#     'is_impossible': False,
#     'question': 'How many maps are in the current instance except the first?'}]},
#  {'context': 'etter is first encountered, it is missing from the mapping, so the  default_factory function calls int() to supply a default count of  zero.  The incr',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 68, 'text': 'default_factory'}],
#     'is_impossible': False,
#     'question': 'What function calls int() to supply a default count of zero?'}]},
#  {'context': 'er(iterable)  d = deque(itertools.islice(it, n-1))  d.appendleft(0)  s = sum(d)  for elem in it:  s += elem - d.popleft()  d.append(elem)  yield s / n',
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 139, 'text': 'yield'}],
#     'is_impossible': False,
#     'question': 'What is s / n?'}]},
#  {'context': ' support  three additional methods and two attributes.  To prevent conflicts with  field names, the method and attribute names start with an underscor',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 56,
#       'text': 'To prevent conflicts with  field names'}],
#     'is_impossible': False,
#     'question': 'Why do method and attribute names start with an underscore?'}]},
#  {'context': "once\n>>> d\ndeque(['g', 'h', 'i', 'j', 'k', 'l'])\n>>> d.rotate(1)  # right rotation\n>>> d\ndeque(['l', 'g', 'h', 'i', 'j', 'k'])\n>>> d.rotate(-1)  # lef",
#   'qas': [{'id': 132,
#     'answers': [{'answer_start': 59,
#       'text': 'make a new deque in reverse order'}],
#     'is_impossible': False,
#     'question': 'What does deque(reversed(d)) do?'}]},
#  {'context': 'odule implements specialized container datatypes providing alternatives to  Python’s general purpose built-in containers, dict, list,  set, and tuple.',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 122, 'text': 'dict, list,  set, and tuple'}],
#     'is_impossible': False,
#     'question': "What are Python's general purpose built in containers?"}]},
#  {'context': 'pproximately the  same O(1) performance in either direction.. Though list objects support similar operations, they are optimized for  fast fixed-lengt',
#   'qas': [{'id': 135,
#     'answers': [{'answer_start': 73, 'text': 'Deque'}],
#     'is_impossible': False,
#     'question': 'What type of object supports the following methods?'}]},
#  {'context': 'ctor, including keyword  arguments.. defaultdict objects support the following method in addition to the  standard dict operations:. defaultdict objec',
#   'qas': [{'id': 129,
#     'answers': [{'answer_start': 65, 'text': 'the following method'}],
#     'is_impossible': False,
#     'question': 'What do defaultdict objects support in addition to the standard dict operations?'}]},
#  {'context': 'ameter.. verbose Changed in version 3.7: Removed the  parameter and the _source attribute.. defaults Changed in version 3.7: Added the  parameter and ',
#   'qas': [{'id': 143,
#     'answers': [{'answer_start': 72, 'text': '_source'}],
#     'is_impossible': False,
#     'question': 'What attribute was removed?'}]},
#  {'context': "_common(10)\n[('the', 1143), ('and', 966), ('to', 762), ('of', 669), ('i', 631),  ('you', 554),  ('a', 546), ('my', 514), ('hamlet', 471), ('in', 451)]",
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 123, 'text': 'hamlet'}],
#     'is_impossible': False,
#     'question': 'What is the most common word in Hamlet?'}]},
#  {'context': ' as dictionary keys  and their counts are stored as dictionary values.  Counts are allowed to be  any integer value including zero or negative counts.',
#   'qas': [{'id': 154,
#     'answers': [{'answer_start': 74, 'text': 'the'}],
#     'is_impossible': False,
#     'question': 'What is expected to be a sequence of elements?'}]},
#  {'context': "\n>>> d = Counter(a=1, b=2, c=3, d=4)\n>>> c.subtract(d)\n>>> c\nCounter({'a': 3, 'b': 0, 'c': -3, 'd': -6}) New in version 3.2.. total Compute the sum of",
#   'qas': [{'id': 133,
#     'answers': [{'answer_start': 74, 'text': 'two'}],
#     'is_impossible': False,
#     'question': 'How many methods work differently for counters?'}]},
#  {'context': 'Bag class  in Smalltalk.. Wikipedia entry for Multisets.. C++ multisets  tutorial with examples.. Knuth, Donald. The Art of Computer Programming Volum',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 0, 'text': 'Bag class  in Smalltalk..'}],
#     'is_impossible': False,
#     'question': 'What is the Wikipedia entry for Multisets?'}]},
#  {'context': ' subclass shown above sets __slots__ to an empty tuple.  This helps  keep memory requirements low by preventing the creation of instance dictionaries.',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 101,
#       'text': 'preventing the creation of instance dictionaries'}],
#     'is_impossible': False,
#     'question': 'What helps keep memory requirements low?'}]},
#  {'context': "ounter(['eggs', 'ham'])\n>>> c['bacon']  # count of a missing element is zero\n0. >>> c['sausage'] = 0  # counter entry with a zero count\n>>> del c['sau",
#   'qas': [{'id': 135,
#     'answers': [{'answer_start': 72, 'text': 'zero\n0'}],
#     'is_impossible': False,
#     'question': 'What is the count of a missing element?'}]},
#  {'context': 'New in version 3.5.. count x x Count the number of deque elements equal to . New in version 3.2.. extend iterable Extend the right side of the deque b',
#   'qas': [{'id': 141,
#     'answers': [{'answer_start': 75, 'text': '.'}],
#     'is_impossible': False,
#     'question': 'What does count x x count the number of deque elements equal to?'}]},
#  {'context': "\n36\n>>> f(2)  # The first request aged out, so don't cache\n4\n>>> f(6)  # Cache hit\n36\n>>> f(4)  # Cache hit and move to front\n16\n>>> list(f.cache.valu",
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 65, 'text': 'f(6)  # Cache hit\n36'}],
#     'is_impossible': False,
#     'question': '# Cache hit and move to front 16 >>> set(f.requests) True >>> list(map(f, [9, 8, 7])?'}]},
#  {'context': 'could The Counter class itself is a dictionary subclass with no  restrictions on its keys and values.  The values are intended to be numbers  represen',
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 6,
#       'text': 'The Counter class itself is a dictionary subclass with no  restrictions on its keys and values.'}],
#     'is_impossible': False,
#     'question': 'The values are intended to be numbers representing counts, but you store anything in the value field?'}]},
#  {'context': 'osite end.  Bounded  length deques provide functionality similar to the tail filter in  Unix. They are also useful for tracking transactions and other',
#   'qas': [{'id': 134,
#     'answers': [{'answer_start': 68, 'text': 'the tail filter'}],
#     'is_impossible': False,
#     'question': 'Bounded length deques provide functionality similar to what in Unix?'}]},
#  {'context': 'typename Returns a new tuple subclass named .  The new subclass is used to  create tuple-like objects that have fields accessible by attribute lookup ',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 0, 'text': 'typename'}],
#     'is_impossible': False,
#     'question': 'what Returns a new tuple subclass named?'}]},
#  {'context': ")\n>>> c.subtract(d)\n>>> c\nCounter({'a': 3, 'b': 0, 'c': -3, 'd': -6}) New in version 3.2.. total Compute the sum of the counts. >>> c = Counter(a=10, ",
#   'qas': [{'id': 150,
#     'answers': [{'answer_start': 24,
#       'text': "c\nCounter({'a': 3, 'b': 0, 'c': -3, 'd': -6}) New in version 3.2.. total Compute the sum of the counts"}],
#     'is_impossible': False,
#     'question': 'What does c.subtract(d) do?'}]},
#  {'context': ' Count the number of deque elements equal to . New in version 3.2.. extend iterable Extend the right side of the deque by appending elements from the ',
#   'qas': [{'id': 125,
#     'answers': [{'answer_start': 72, 'text': 'Deques'}],
#     'is_impossible': False,
#     'question': 'What is short for "double-ended queue"?'}]},
#  {'context': 'Ordered dictionaries are just like regular dictionaries but have some extra  capabilities relating to ordering operations.  They have become less  imp',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 35, 'text': 'regular'}],
#     'is_impossible': False,
#     'question': 'Ordered dictionaries are similar to what other type of dictionary?'}]},
#  {'context': 'y are optimized for  fast fixed-length operations and incur O(n) memory movement costs for  pop(0) and insert(0, v) operations which change both the s',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 62, 'text': 'O(n) memory movement costs'}],
#     'is_impossible': False,
#     'question': 'List objects are optimized for fast fixed-length operations and incur what?'}]},
#  {'context': ' the most recent activity is of interest.. Deque objects support the following methods:. Deque objects also provide one read-only attribute:. . . . . ',
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 60,
#       'text': 'thread-safe, memory  efficient'}],
#     'is_impossible': False,
#     'question': 'Deques support what kind of appends and pops?'}]},
#  {'context': "-toplevel-  d.pop()\nIndexError: pop from an empty deque \n>>> d.extendleft('abc')  # extendleft() reverses the input order\n>>> d\ndeque(['c', 'b', 'a'])",
#   'qas': [{'id': 134,
#     'answers': [{'answer_start': 126, 'text': 'd\ndeque'}],
#     'is_impossible': False,
#     'question': 'How does extendleft() reverse the input order?'}]},
#  {'context': 'A Counter is a dict subclass for counting hashable objects.  It is a collection where elements are stored as dictionary keys  and their counts are sto',
#   'qas': [{'id': 151,
#     'answers': [{'answer_start': 2, 'text': 'Counter'}],
#     'is_impossible': False,
#     'question': 'What is the name of the class that computes the sum of the counts?'}]},
#  {'context': 'The class, UserString acts as a wrapper around string objects.  The need for this class has been partially supplanted by the ability to  subclass dire',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 11, 'text': 'UserString'}],
#     'is_impossible': False,
#     'question': 'What class acts as a wrapper around string objects?'}]},
#  {'context': 'namedtuple() factory function for creating tuple subclasses with named fields. deque list-like container with fast appends and pops on either end. Cha',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 0, 'text': 'namedtuple()'}],
#     'is_impossible': False,
#     'question': 'What is the factory function for creating tuple subclasses with named fields?'}]},
#  {'context': "er(a=4, b=2, c=0, d=-2)\n>>> sorted(c.elements())\n['a', 'a', 'a', 'a', 'b', 'b']. most_common n n n all Return a list of the  most common elements and ",
#   'qas': [{'id': 144,
#     'answers': [{'answer_start': 1,
#       'text': 'most_common n n n all Return a list of the  most common elements and their counts from the  most common to the least.  If  is omitted or None,  most_common()'}],
#     'is_impossible': False,
#     'question': 'What return a list of the most common elements?'}]},
#  {'context': 'ged in version 3.7: Removed the  parameter and the _source attribute.. defaults Changed in version 3.7: Added the  parameter and the _field_defaults  ',
#   'qas': [{'id': 130,
#     'answers': [{'answer_start': 67, 'text': 'positional names'}],
#     'is_impossible': False,
#     'question': 'What do invalid fieldnames automatically be replaced with?'}]},
#  {'context': 'To convert a dictionary to a named tuple, use the double-star-operator  (as described in Unpacking Argument Lists):',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 50, 'text': 'double-star-operator'}],
#     'is_impossible': False,
#     'question': 'What is used to convert a dictionary to a named tuple?'}]},
#  {'context': 'See typing.NamedTuple for a way to add type hints for named  tuples.  It also provides an elegant notation using the class  keyword: class Component(N',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 4, 'text': 'typing.NamedTuple'}],
#     'is_impossible': False,
#     'question': 'What is a way to add type hints for named tuples?'}]},
#  {'context': "s may be zero or negative. >>> c = Counter(a=4, b=2, c=0, d=-2)\n>>> d = Counter(a=1, b=2, c=3, d=4)\n>>> c.subtract(d)\n>>> c\nCounter({'a': 3, 'b': 0, '",
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 72, 'text': 'Counter'}],
#     'is_impossible': False,
#     'question': 'What class is similar to bags or multisets in other languages?'}]},
#  {'context': 'ge which mappings are searched.  The list should  always contain at least one mapping.. new_child m = None ** kwargs Returns a new ChainMap containing',
#   'qas': [{'id': 126,
#     'answers': [{'answer_start': 64, 'text': 'The underlying mappings'}],
#     'is_impossible': False,
#     'question': 'What is stored in a list?'}]},
#  {'context': 'r, including keyword  arguments.. defaultdict objects support the following method in addition to the  standard dict operations:. defaultdict objects ',
#   'qas': [{'id': 135,
#     'answers': [{'answer_start': 69, 'text': '__missing__()'}],
#     'is_impossible': False,
#     'question': 'What is called for any operations besides __getitem__()?'}]},
#  {'context': 'e.. appendleft x x Add  to the left side of the deque.. clear Remove all elements from the deque leaving it with length 0.. copy Create a shallow copy',
#   'qas': [{'id': 139,
#     'answers': [{'answer_start': 69, 'text': 'all elements'}],
#     'is_impossible': False,
#     'question': 'What does clear remove from the deque leaving it with length 0.'}]},
#  {'context': '  self.maxrequests = maxrequests  # max number of uncached requests  self.maxsize = maxsize  # max number of stored return values  self.cache_after = ',
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 69, 'text': 'self.maxsize'}],
#     'is_impossible': False,
#     'question': 'what is the max size number of stored return values?'}]},
#  {'context': 'e contents of the  UserString class.. Changed in version 3.5: New methods __getnewargs__, __rmod__, casefold,  format_map, isprintable, and maketrans.',
#   'qas': [{'id': 129,
#     'answers': [{'answer_start': 74,
#       'text': '__getnewargs__, __rmod__, casefold,  format_map, isprintable, and maketrans'}],
#     'is_impossible': False,
#     'question': 'What new methods were added in version 3.5?'}]},
#  {'context': ' to  create a single, updateable view.  If no  are specified, a single empty  dictionary is provided so that a new chain always has at least one mappi',
#   'qas': [{'id': 141,
#     'answers': [{'answer_start': 69, 'text': 'an empty dict'}],
#     'is_impossible': False,
#     'question': 'If not specified, what is used?'}]},
#  {'context': "', 'j']) \n>>> d.pop()  # return and remove the rightmost item\n'j'\n>>> d.popleft()  # return and remove the leftmost item\n'f'\n>>> list(d)  # list the c",
#   'qas': [{'id': 128,
#     'answers': [{'answer_start': 70, 'text': 'd.popleft()'}],
#     'is_impossible': False,
#     'question': "What does and remove the leftmost item 'f'?"}]},
#  {'context': 'xcept that they return a zero  count for missing items instead of raising a KeyError:. Setting a count to zero does not remove an element from a count',
#   'qas': [{'id': 155,
#     'answers': [{'answer_start': 66, 'text': 'raising a KeyError'}],
#     'is_impossible': False,
#     'question': 'What does the count instead of replacing them do?'}]},
#  {'context': ")  # left rotation\n>>> d\ndeque(['g', 'h', 'i', 'j', 'k', 'l']) \n>>> deque(reversed(d))  # make a new deque in reverse order\ndeque(['l', 'k', 'j', 'i',",
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 49, 'text': 'ghi'}],
#     'is_impossible': False,
#     'question': 'From collections import deque?'}]},
#  {'context': "xample 'x y' or 'x, y'.. class for return global pass raise Any valid Python identifier may be used for a fieldname except for names  starting with an",
#   'qas': [{'id': 124,
#     'answers': [{'answer_start': 66, 'text': 'tuple-like objects'}],
#     'is_impossible': False,
#     'question': 'What is the new subclass used to create?'}]},
#  {'context': 'ose rename Changed in version 3.6: The  and  parameters became  keyword-only arguments.. module Changed in version 3.6: Added the  parameter.. verbose',
#   'qas': [{'id': 134,
#     'answers': [{'answer_start': 39,
#       'text': 'fields with a default value must come after any fields without a  default'}],
#     'is_impossible': False,
#     'question': 'Why are fields with a default value applied to the rightmost parameters?'}]},
#  {'context': "n  element’s count is less than one, elements() will ignore it. >>> c = Counter(a=4, b=2, c=0, d=-2)\n>>> sorted(c.elements())\n['a', 'a', 'a', 'a', 'b'",
#   'qas': [{'id': 137,
#     'answers': [{'answer_start': 72, 'text': 'Counter'}],
#     'is_impossible': False,
#     'question': 'What subclass inherited the capability to remember insertion order?'}]},
#  {'context': ':. Counter objects have a dictionary interface except that they return a zero  count for missing items instead of raising a KeyError:. Setting a count',
#   'qas': [{'id': 134,
#     'answers': [{'answer_start': 72, 'text': 'zero\n0'}],
#     'is_impossible': False,
#     'question': '# a new counter from an iterable >>> c = Counter(cats=4, dogs=8) What is the count of a missing element?'}]},
#  {'context': 'e is inserted in  the dictionary for the , and returned. If calling default_factory raises an exception this exception is  propagated unchanged. This ',
#   'qas': [{'id': 132,
#     'answers': [{'answer_start': 68, 'text': 'default_factory'}],
#     'is_impossible': False,
#     'question': 'If calling what raises an exception this exception is raised?'}]},
#  {'context': 'the new map at the front of the list of mappings; if not  specified, an empty dict is used, so that a call to d.new_child()  is equivalent to: ChainMa',
#   'qas': [{'id': 141,
#     'answers': [{'answer_start': 69, 'text': 'an empty dict'}],
#     'is_impossible': False,
#     'question': 'If not specified, what is used?'}]},
#  {'context': 'e variable:. . . __missing__ key key If the default_factory attribute is None, this raises a  KeyError exception with the  as argument. key key If def',
#   'qas': [{'id': 127,
#     'answers': [{'answer_start': 66, 'text': 'The first argument'}],
#     'is_impossible': False,
#     'question': 'What provides the initial value for the default_factory attribute?'}]},
#  {'context': 'this exception is  propagated unchanged. This method is called by the __getitem__() method of the  dict class when the requested key is not found; wha',
#   'qas': [{'id': 136,
#     'answers': [{'answer_start': 73, 'text': 'None'}],
#     'is_impossible': False,
#     'question': 'What will get(), like normal dictionaries, return instead of using default_factory?'}]},
#  {'context': 't has a move_to_end() method to efficiently  reposition an element to an endpoint.. A regular dict can emulate OrderedDict’s od.move_to_end(k,\nlast=Tr',
#   'qas': [{'id': 123,
#     'answers': [{'answer_start': 70, 'text': 'an endpoint'}],
#     'is_impossible': False,
#     'question': 'OrderedDict has a move_to_end() method to efficiently reposition an element to what?'}]},
#  {'context': 'nge both the size and  position of the underlying data representation.. maxlen If  is not specified or is None, deques may grow to an  arbitrary lengt',
#   'qas': [{'id': 156,
#     'answers': [{'answer_start': 78, 'text': 'maxlen'}],
#     'is_impossible': False,
#     'question': 'What is the maximum size of a deque or None if unbounded?'}]},
#  {'context': 'pute the sum of the counts. >>> c = Counter(a=10, b=5, c=0)\n>>> c.total()\n15 New in version 3.10.. fromkeys iterable This class method is not implemen',
#   'qas': [{'id': 142,
#     'answers': [{'answer_start': 74, 'text': '>>>'}],
#     'is_impossible': False,
#     'question': "If an element's count is less than one, elements() will ignore it."}]}]

# %%
wandb server start
# Out:
# UsageError: unrecognized arguments: start

# %%
# Evaluate the model
result, texts = model.eval_model(test)
# Out:
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Make predictions with the model
to_predict = [
    {
        "context": "k”  and is short for “double-ended queue”).  Deques support thread-safe, memory  efficient appends and pops from either side of the deque with approxi",
        "qas": [
            {
                "question": "Deques support what kind of appends and pops?",
                "id": "126",
            }
        ],
    }
]

# %%
answers, probabilities = model.predict(to_predict)

print(answers)
# Out:
# convert squad examples to features: 100%|██████████| 1/1 [00:00<00:00, 170.62it/s]
# add example index and unique id: 100%|██████████| 1/1 [00:00<00:00, 10538.45it/s]
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '126', 'answer': []}]
